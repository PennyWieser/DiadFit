# %% [markdown]
# ## Fitting Ne lines in a loop
# - This notebook shows how to fit all lines in a folder defined by path
# - You tweak the fit for a single line, and then use this to fit all lines. You can then refit lines with high residuals/offsets differing from the rest

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf

# %% [markdown]
# ## Choose path and extract files here

# %%
path=r'C:\Users\penny\OneDrive - Oregon State University\Postdoc\MeltInclusion_SampleStuff\Peak_Fitting_Tests\Example_notebooks_Spectra\Ne_Test_Loop'
filetype='headless_txt'
# Put the common string you can in all your Ne lines here
ID_str='NE'
file_fmt='txt'
exclude_str='png'
# If you added a prefix in Witec, e.g. 01, removes when svaing the Ne line name 
prefix=False
Ne_files=pf.get_Ne_files(path=path, ID_str=ID_str, exclude_str=exclude_str, sort=True)

# %% [markdown]
# ## Fit 1 spectra, and check you are happy with the parameters
# - First plot i, and check peak postion.

# %%
filename=Ne_files[1]  # Or you could put a string here, like 'NE1.txt' 
# You might need to adjust if your spectra is way off
peak1_cent=1123
peak2_cent=1453


Ne, df_sort_Ne_trim, nearest_1117, nearest_1447=pf.plot_Ne_lines(path=path, filename=filename, filetype=filetype, 
n_peaks=6, peak1_cent=peak1_cent, peak2_cent=peak2_cent,
height=10, threshold=0.6, distance=1, prominence=10, width=1, exclude_range_1=None,
exclude_range_2=None)
# Out:
# 1123.096389
# 1453.279186

# %% [markdown]
# ## Now tweak the fit for this 1 example
# - Most important things, the number of peaks you want for 1117, and the offset for this peak (LH_offset_min)

# %%
#If you have weak Ne lines and no secondary peak, set to 1
peaks_1=2
# Determines how far from the peak center the 2nd peak is. 
LH_offset_mini=[2, 5]
# If fit really bad, try tweaking the amplitude here
amplitude=100
#x_range - Determins how much outside your selected background position the plot shows
x_range=50
# Y range- Determins how much y axis you get above the baseline on the plot
y_range=200
# Backgrounds, relative to peak center. Adjust in function. 

# To see other parameters you can tweak, do help(pf.fit_Ne_lines) if this isn't working fo your spectra. 
df_test, Ne_1117_reg_x_plot, Ne_1117_reg_y_plot=pf.fit_Ne_lines(
Ne=Ne, filename=filename, path=path, prefix=prefix,
LH_offset_mini=LH_offset_mini, peaks_1=peaks_1,
Ne_center_1=nearest_1117, Ne_center_2=nearest_1447,
lower_bck_pk1=[-50, -25], upper_bck1_pk1=[8, 13], upper_bck2_pk1=[50, 80],
lower_bck_pk2=[-40, -30], upper_bck1_pk2=[15, 50], upper_bck2_pk2=[50, 80],
amplitude=amplitude, x_range=x_range, y_range=y_range)

df_test
# Out:
# first iteration, peak Center=1122.8294
# first iteration, peak Amplitude=1457.2183
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
#   File_Name  1447_peak_cent  error_1447  1117_peak_cent  error_1117  \
# 0  NE10.txt     1453.400724      0.0094     1122.834383         NaN
#
#      deltaNe   Ne_Corr  Ne_Corr_min  Ne_Corr_max  residual_1447  residual_1117
# 0  330.56634  0.999732          NaN          NaN     146.961755       7.027703

# %% [markdown]
# ## Now you can loop over all files using these parameters
# - Most important thing you can change is plot_figure=False, much quicker, but wont save or show figures, plot_figure=True will)
# - If you need, you can add other parameters in the loop here.

# %%
plot_figure=False # Means doesnt make figures, lot faster. 
save_excel=True # Saves to excel
save_clipboard=True # Copies to clipboard

df = pd.DataFrame([])
for i in range(0, len(Ne_files)):
    
    filename=Ne_files[i]
    Ne=pf.get_data(path=path, filename=filename, filetype=filetype)
    print('working on ' + str(Ne_files[i]))

    data=pf.fit_Ne_lines(Ne=Ne, filename=filename, path=path, prefix=prefix,
LH_offset_mini=LH_offset_mini, peaks_1=peaks_1, Ne_center_1=nearest_1117, Ne_center_2=nearest_1447, amplitude=amplitude, plot_figure=plot_figure, loop=True)

    df = df.append(data)
    
df.to_excel('Ne_Lines_fit_loop.xlsx')
df.to_clipboard(excel=True)
# Out:
# working on NE1.txt
# first iteration, peak Center=1122.8503
# first iteration, peak Amplitude=1388.5051
# Trying to place second peak between 1117.85and1120.85
# Error bars not determined by function
# working on NE10.txt
# first iteration, peak Center=1122.8294
# first iteration, peak Amplitude=1447.5943
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE11.txt
# first iteration, peak Center=1122.8233
# first iteration, peak Amplitude=1447.2443
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE12.txt
# first iteration, peak Center=1122.8176
# first iteration, peak Amplitude=1434.2487
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE13.txt
# first iteration, peak Center=1122.8237
# first iteration, peak Amplitude=1441.9248
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE14.txt
# first iteration, peak Center=1122.749
# first iteration, peak Amplitude=1628.0606
# Trying to place second peak between 1117.75and1120.75
# Error bars not determined by function
# working on NE15.txt
# first iteration, peak Center=1122.8296
# first iteration, peak Amplitude=1378.6328
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE16.txt
# first iteration, peak Center=1122.8359
# first iteration, peak Amplitude=1406.5836
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE17.txt
# first iteration, peak Center=1122.8176
# first iteration, peak Amplitude=1386.9442
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE18.txt
# first iteration, peak Center=1122.8309
# first iteration, peak Amplitude=1573.4966
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE19.txt
# first iteration, peak Center=1122.8073
# first iteration, peak Amplitude=1338.1615
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE2.txt
# first iteration, peak Center=1122.8559
# first iteration, peak Amplitude=1328.8219
# Trying to place second peak between 1117.86and1120.86
# Error bars not determined by function
# working on NE20.txt
# first iteration, peak Center=1122.8151
# first iteration, peak Amplitude=1342.5175
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE21.txt
# first iteration, peak Center=1122.8298
# first iteration, peak Amplitude=1320.2058
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE22.txt
# first iteration, peak Center=1122.8234
# first iteration, peak Amplitude=1300.8107
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE23.txt
# first iteration, peak Center=1122.7059
# first iteration, peak Amplitude=843.4265
# Trying to place second peak between 1117.71and1120.71
# Error bars not determined by function
# working on NE24.txt
# first iteration, peak Center=1122.818
# first iteration, peak Amplitude=1275.326
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE25.txt
# first iteration, peak Center=1122.8263
# first iteration, peak Amplitude=1212.2776
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE26.txt
# first iteration, peak Center=1122.8257
# first iteration, peak Amplitude=1266.7544
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE27.txt
# first iteration, peak Center=1122.83
# first iteration, peak Amplitude=1261.177
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE28.txt
# first iteration, peak Center=1122.8313
# first iteration, peak Amplitude=1299.391
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE29.txt
# first iteration, peak Center=1122.8253
# first iteration, peak Amplitude=1279.2378
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE3.txt
# first iteration, peak Center=1122.8545
# first iteration, peak Amplitude=1407.1337
# Trying to place second peak between 1117.85and1120.85
# Error bars not determined by function
# working on NE30.txt
# first iteration, peak Center=1122.8294
# first iteration, peak Amplitude=1306.4323
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE31.txt
# first iteration, peak Center=1122.8165
# first iteration, peak Amplitude=1301.7373
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE32.txt
# first iteration, peak Center=1122.8171
# first iteration, peak Amplitude=1338.5408
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE33.txt
# first iteration, peak Center=1122.8238
# first iteration, peak Amplitude=1360.3535
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE34.txt
# first iteration, peak Center=1122.8293
# first iteration, peak Amplitude=1325.621
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE35.txt
# first iteration, peak Center=1122.8188
# first iteration, peak Amplitude=1310.5268
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE36.txt
# first iteration, peak Center=1122.8194
# first iteration, peak Amplitude=1332.2055
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE37.txt
# first iteration, peak Center=1122.8136
# first iteration, peak Amplitude=1313.7848
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE38.txt
# first iteration, peak Center=1122.8154
# first iteration, peak Amplitude=1304.1595
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE39.txt
# first iteration, peak Center=1122.8146
# first iteration, peak Amplitude=1309.3491
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE4.txt
# first iteration, peak Center=1122.8435
# first iteration, peak Amplitude=1486.1738
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE40.txt
# first iteration, peak Center=1122.8078
# first iteration, peak Amplitude=1322.8378
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE41.txt
# first iteration, peak Center=1122.8094
# first iteration, peak Amplitude=1326.6357
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE42.txt
# first iteration, peak Center=1122.8041
# first iteration, peak Amplitude=1322.6916
# Trying to place second peak between 1117.8and1120.8
# Error bars not determined by function
# working on NE43.txt
# first iteration, peak Center=1122.7976
# first iteration, peak Amplitude=1336.3929
# Trying to place second peak between 1117.8and1120.8
# Error bars not determined by function
# working on NE44.txt
# first iteration, peak Center=1122.8037
# first iteration, peak Amplitude=1305.5175
# Trying to place second peak between 1117.8and1120.8
# Error bars not determined by function
# working on NE45.txt
# first iteration, peak Center=1122.8067
# first iteration, peak Amplitude=1284.532
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE46.txt
# first iteration, peak Center=1122.8052
# first iteration, peak Amplitude=1349.5284
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE47.txt
# first iteration, peak Center=1122.8146
# first iteration, peak Amplitude=1348.1605
# Trying to place second peak between 1117.81and1120.81
# Error bars not determined by function
# working on NE48.txt
# first iteration, peak Center=1122.8209
# first iteration, peak Amplitude=1323.459
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE49.txt
# first iteration, peak Center=1122.8212
# first iteration, peak Amplitude=1241.9589
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE5.txt
# first iteration, peak Center=1122.8449
# first iteration, peak Amplitude=1505.0273
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE50.txt
# first iteration, peak Center=1122.8163
# first iteration, peak Amplitude=1248.0206
# Trying to place second peak between 1117.82and1120.82
# Error bars not determined by function
# working on NE51.txt
# first iteration, peak Center=1122.8455
# first iteration, peak Amplitude=1339.1302
# Trying to place second peak between 1117.85and1120.85
# Error bars not determined by function
# working on NE52.txt
# first iteration, peak Center=1122.832
# first iteration, peak Amplitude=1309.1561
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
# working on NE53.txt
# first iteration, peak Center=1122.8398
# first iteration, peak Amplitude=1303.4043
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE54.txt
# first iteration, peak Center=1122.8407
# first iteration, peak Amplitude=1393.4673
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE6.txt
# first iteration, peak Center=1122.847
# first iteration, peak Amplitude=1294.4885
# Trying to place second peak between 1117.85and1120.85
# Error bars not determined by function
# working on NE7.txt
# first iteration, peak Center=1122.8373
# first iteration, peak Amplitude=1498.5048
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE8.txt
# first iteration, peak Center=1122.8381
# first iteration, peak Amplitude=1483.2491
# Trying to place second peak between 1117.84and1120.84
# Error bars not determined by function
# working on NE9.txt
# first iteration, peak Center=1122.8311
# first iteration, peak Amplitude=1453.1598
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function

# %% [markdown]
# ## Look at residuals to work out if you need to fit some by hand

# %%
# Identify ones more than x sigma outside the mean of the splitting

Std_split=np.std(df['Ne_Corr'])
Mean_split=np.mean(df['Ne_Corr'])
# How many sigma outside mean splitting you want to consider
sigma=2

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13,5))
ax1.plot(df['Ne_Corr'], df['residual_1117'], 'ok', mfc='black')
ax2.plot(df['Ne_Corr'], df['residual_1447'], 'ok', mfc='black')
ax1.set_xlabel('Ne correction factor')
ax2.set_xlabel('Ne correction factor')
ax1.set_ylabel('Residual Peak 1')
ax2.set_ylabel('Residual peak 2')



outlier=df.loc[abs(Mean_split-df['Ne_Corr'])>Std_split*2]
ax1.plot(outlier['Ne_Corr'], outlier['residual_1117'], 'ok', mfc='red')
ax2.plot(outlier['Ne_Corr'], outlier['residual_1447'], 'ok', mfc='red')
print('outliers')
outlier
# Out:
# outliers
#   File_Name  1447_peak_cent  error_1447  1117_peak_cent  error_1117  \
# 0  NE50.txt     1453.060479      0.0718     1122.821643         NaN
#
#       deltaNe   Ne_Corr  Ne_Corr_min  Ne_Corr_max  residual_1447  \
# 0  330.238836  1.000723          NaN          NaN     565.537873
#
#    residual_1117
# 0       8.348504

# %% [markdown]
# ## Manually fit ones you aren't happy with, and hand paste in

# %%
filename='NE50.txt'
#If you have weak Ne lines and no secondary peak, set to 1
peaks_1=2
# If weak, set to 10
LH_offset_mini=[2, 5]
# If fit really bad, try tweaking the amplitude here
amplitude=100
x_range=50
# Y range- Determins how much y axis you get above the baseline on the plot
y_range=200
# Backgrounds, relative to peak center. Adjust in function.

# To see other parameters you can tweak, do help(pf.fit_Ne_lines) if this isn't working fo your spectra. 
df_test, Ne_1117_reg_x_plot, Ne_1117_reg_y_plot=pf.fit_Ne_lines(
Ne=Ne, filename=filename, path=path, prefix=prefix,
LH_offset_mini=LH_offset_mini, peaks_1=peaks_1,
Ne_center_1=nearest_1117, Ne_center_2=nearest_1447,
amplitude=amplitude,
x_span_1=[-10, 8],
lower_bck_pk1=[-50, -25], upper_bck1_pk1=[8, 15], upper_bck2_pk1=[30, 50],
N_poly_2_baseline=1, x_span_2=[-5, 5],
lower_bck_pk2=[-40, -30], upper_bck1_pk2=[15, 50], upper_bck2_pk2=[50, 51],
x_range=x_range, y_range=y_range)

df_test
# Out:
# first iteration, peak Center=1122.8311
# first iteration, peak Amplitude=1453.1598
# Trying to place second peak between 1117.83and1120.83
# Error bars not determined by function
#   File_Name  1447_peak_cent  error_1447  1117_peak_cent  error_1117  \
# 0  NE50.txt     1453.409184     0.00929     1122.834465         NaN
#
#      deltaNe   Ne_Corr  Ne_Corr_min  Ne_Corr_max  residual_1447  residual_1117
# 0  330.57472  0.999706          NaN          NaN     140.993736       7.483956
