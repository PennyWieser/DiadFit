# %% [markdown]
# ## This notebook shows screenshots of accepted file formats, if you have a different format, please email penny!

# %% [markdown]
# ### 1. "headless txt": txt file with no headers, wavenumber 1st column, intensity second
# ![image.png](attachment:6501b639-149c-445b-b4b8-3c2805ca022f.png)

# %% [markdown]
# ### 2. "Witec_ASCII"
# ![image.png](attachment:75f9d2d4-e0a9-4ae4-9a49-cc7ef2cce778.png)

# %% [markdown]
# ### 3. 'Renishaw_txt', kindly provided by Felix Boschetty
# ![image.png](attachment:c2e6c290-527f-4510-9379-f2393dedefa9.png)

# %% [markdown]
# ### 4. 'HORIBA_txt', Kindly provided by Sarah Hickernell
# ![image.png](attachment:3b53a0b4-0dfa-46b1-b0d4-b89091a94a99.png)

# %% [markdown]
# ### 5. 'headless_csv', Kindly provided by Chelsea Allison
# ![image.png](attachment:c2ed39b1-ba75-4afc-95df-2f0de2440efb.png)
