# %% [markdown]
# # Headless CSV file
# This notebook shows how to fit a Fermi diad from a CSV file collected at a wide range of wavenumbers

# %%
# !pip install "https://github.com/PennyWieser/DiadFit/archive/refs/tags/0.0.2.zip"
# Out:
# Collecting https://github.com/PennyWieser/DiadFit/archive/refs/tags/0.0.2.zip
#   Using cached https://github.com/PennyWieser/DiadFit/archive/refs/tags/0.0.2.zip
# Requirement already satisfied: pandas in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from DiadFit==0.0.2.dev0) (1.4.2)
# Requirement already satisfied: numpy in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from DiadFit==0.0.2.dev0) (1.21.5)
# Requirement already satisfied: matplotlib in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from DiadFit==0.0.2.dev0) (3.5.1)
# Requirement already satisfied: scikit-learn in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from DiadFit==0.0.2.dev0) (1.0.2)
# Requirement already satisfied: scipy in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from DiadFit==0.0.2.dev0) (1.7.3)
# Requirement already satisfied: lmfit in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from DiadFit==0.0.2.dev0) (1.0.3)
# Requirement already satisfied: uncertainties>=3.0.1 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from lmfit->DiadFit==0.0.2.dev0) (3.1.6)
# Requirement already satisfied: asteval>=0.9.22 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from lmfit->DiadFit==0.0.2.dev0) (0.9.23)
# Requirement already satisfied: future in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from uncertainties>=3.0.1->lmfit->DiadFit==0.0.2.dev0) (0.18.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->DiadFit==0.0.2.dev0) (21.3)
# Requirement already satisfied: six>=1.5 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->DiadFit==0.0.2.dev0) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from pandas->DiadFit==0.0.2.dev0) (2022.1)
# Requirement already satisfied: joblib>=0.11 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->DiadFit==0.0.2.dev0) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/kyledayton/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn->DiadFit==0.0.2.dev0) (2.2.0)

# %%
# Importing numpy, pandas and matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Importing DiadFit after its installed. If its not installed, see paper for installation instructions
import DiadFit as pf

# %% [markdown]
# ## Specify path to folder with your spectra in

# %%
# Add the path with your spectra in
mypath=r'G:\My Drive\Berkeley_NEW\DiadFit_outer\Testing'

# %% [markdown]
# ## Specify your file type, options:
# - 'headless_txt',
# -'Witec_ASCII'
# - 'Renishaw_txt'
# - 'HORIBA_txt'
# - 'headless_csv'

# %%
filetype='headless_txt'
# Specifying the extension here helps to filter out other file types,
# e.g. png files that may be in the folder
file_ext='.txt'
# If your instrument appends a nubmer like 01, 02 to each file, True removes it
prefix=False

# %% [markdown]
# ## This function finds all files in your path with the specified file format

# %%
Diad_files=pf.get_diad_files(path=mypath, file_ext=file_ext)
Diad_files
# Out:
# exclude type
# .png
# ['01 LM4 G1 FI1.txt']

# %% [markdown]
# ## Select file here OR specify file name
# - Here we select the 1st file in the folder [0], if you wanted to target a specific file, you can do that by uncommenting the line below.

# %%
filename='01 LM4 G1 FI1.txt' # or put ='FG04_10_MI1_2.txt'
#filename='WITEC_ASCII_MS14_11_MI1_50X.txt'
print(filename)
# Out:
# 01 LM4 G1 FI1.txt

# %% [markdown]
# ## Now plot the spectra to inspect what is going on
# - By default, DiadFit adds the positions of some common phases in bubbles

# %%
pf.plot_diad(path=mypath, filename=filename, filetype=filetype)
plt.savefig('plot_diad_example.png', dpi=200)

# %% [markdown]
# ## After inspecting the spectra, decide if you want to fit the carbonate peak
# - If yes, select fit_carbonate=True, else fit_Carbonate=False
# - We can see above there is no carbonate, so we select false

# %%
fit_carbonate=False
# Exclude a range here, e.g. if you have a nasty Cosmic ray
exclude_range=None#[1080, 1088]
# This selects the two background positions
lower_range=[1060, 1065]
upper_range=[1120, 1130]
# Tweak degree of poylnomial fitting the background
N_poly=1
# This sets the peak center, you can tweak if needed
cent=1090
# Amplitude, may need to tweak
amplitude=1000

# Select sigma level, e.g. discard points in background N* sigma outside mean
outlier_sigma=12
# N PEAKS - if you want approx peak positionYs
N_peaks=3

# This actually does the work and fits the carbonate peak
# You can tweak the other parameters such as the distance, prominence in the function
Carb_fit=pf.fit_carbonate_peak(path=mypath, 
filename=filename, filetype=filetype,
lower_range=lower_range, upper_range=upper_range, 
cent=cent, exclude_range=exclude_range,
N_poly=N_poly, outlier_sigma=outlier_sigma, 
N_peaks=N_peaks, amplitude=amplitude,
distance = 10, prominence=5, width=6, 
threshold=0.1, fit_carbonate=fit_carbonate)
Carb_fit

# %% [markdown]
# ## Now lets plot the diads
# - As with carbonate, you can exclude 2 segments (e.g. around cosmic rays)
# - You then specify how many peaks you want to fit on each diad. 1 means just the strong peak, 2 hotbands, and 3 for Diad2 would also fit the C13 peak if present.
# - The identify_diad_peaks then uses scipy findpeaks to identify the positions of the 2 diads, and any other peaks the user asks for. These are saved, and fed into the later functions for peak fitting.

# %%
# Exclude a range
exclude_range1=None #[1320, 1340]#None
exclude_range2=None #[1236, 1250]
# Specify the number of peaks
n_peaks_diad1=2
n_peaks_diad2=2 
# 
diad1_peaks, diad2_peaks=pf.identify_diad_peaks(path=mypath, filename=filename,
filetype=filetype, n_peaks_diad1=n_peaks_diad1, n_peaks_diad2=n_peaks_diad2,                                      
exclude_range1=exclude_range1,  exclude_range2=exclude_range2,
height = 400, threshold = 0.5, distance = 5, prominence=10, width=0.5)
# Out:
# Couldnt find diad2, set peak guess to 1389.1, 1410
# Couldnt find diad1, set peak guess to 1286.1
# Initial estimates: Diad1+HB=[1286.1], Diad2+HB=[1389.1 1410. ]

# %% [markdown]
# ## If you have no diads visible...
# - Uncomment this line, and it will just save the carbonate peak parameters

# %%
#pf.proceed_to_fit_diads(filename, Carb_fit)

# %% [markdown]
# ## Fit Diad 1
# - This function uses the guess of the peak parameters above. You can choose to fit a gaussian background. Else, use a polynomial and specify background positions
# - If plot_figure=True, it saves the figure in its own folder in the path, so you can inspect all the fits at a later date.

# %%
# If you put a number in brackets, it'll center a gaussian near there. 
peak_pos_gauss=None#(1250)
# Degree of polynomial for the background
N_poly_bck_diad1=1
# LH range to use as baseline for the diad
lower_baseline_diad1=[1220, 1250]
# RH range to use as baseline for the diad
upper_baseline_diad1=[1300, 1350]
## Amplitude may need tweaking if you don't get a good match
amplitude=1000
# Do you want to save the figure?
plot_figure=True
# This function does the work fitting the diad
Diad1_fit=pf.fit_diad_1_w_bck(
path=mypath, filename=filename, filetype=filetype,
exclude_range1=exclude_range1, exclude_range2=exclude_range2,
N_poly_bck_diad1=N_poly_bck_diad1, lower_baseline_diad1=lower_baseline_diad1,
upper_baseline_diad1=upper_baseline_diad1,
peak_pos_voigt=diad1_peaks, peak_pos_gauss=peak_pos_gauss, amplitude=amplitude,
plot_figure=plot_figure)
Diad1_fit
# Out:
#     Diad1_Cent  Diad1_Area  Residual_Diad1
# 0  1282.301389   -3.632428        1.121087

# %% [markdown]
# ## Fit diad 2

# %%
# Gaussian or not, either enter approximate center of Guassian, or None
peak_pos_gauss=None#(1378)
# If need to adjust shape of gaussian, enter fwhm here
gauss_sigma=100
gauss_sigma_min=10
gauss_amp=30000
# Degree of polynomail for the background
N_poly_bck_diad2=2
# LH range to use as baseline for the diad
lower_baseline_diad2=[1300, 1360]
# RH range to use as baseline for the diad
upper_baseline_diad2=[1440, 1470]
# Tweak amplitude if needed
amplitude=10000
# This then takes these inputs and feeds them into the function
Diad2_fit=pf.fit_diad_2_w_bck(path=mypath, filename=filename, filetype=filetype, peak_pos_voigt=diad2_peaks,
exclude_range1=exclude_range1, exclude_range2=exclude_range2, N_poly_bck_diad2=N_poly_bck_diad2, 
lower_baseline_diad2=lower_baseline_diad2, upper_baseline_diad2=upper_baseline_diad2,
peak_pos_gauss=peak_pos_gauss, gauss_sigma=gauss_sigma,gauss_fwhm_min=gauss_sigma_min,
gauss_amp=gauss_amp,                                                                         
amplitude=amplitude)
Diad2_fit
# Out:
# 1402.3483194136002
# <Parameter 'sigma', value=5.175027633398637 +/- 3.74, bounds=[0:inf]>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [18], in <cell line: 16>()
#      14 amplitude=10000
#      15 # This then takes these inputs and feeds them into the function
# ---> 16 Diad2_fit=pf.fit_diad_2_w_bck(path=mypath, filename=filename, filetype=filetype, peak_pos_voigt=diad2_peaks,
#      17 exclude_range1=exclude_range1, exclude_range2=exclude_range2, N_poly_bck_diad2=N_poly_bck_diad2,
#      18 lower_baseline_diad2=lower_baseline_diad2, upper_baseline_diad2=upper_baseline_diad2,
#      19 peak_pos_gauss=peak_pos_gauss, gauss_sigma=gauss_sigma,gauss_fwhm_min=gauss_sigma_min,
#      20 gauss_amp=gauss_amp,
#      21 amplitude=amplitude)
#      22 Diad2_fit
#
# File g:\my drive\berkeley_new\diadfit_outer\src\DiadFit\diads.py:1231, in fit_diad_2_w_bck(path, filename, filetype, exclude_range1, exclude_range2, amplitude, N_poly_bck_diad2, lower_baseline_diad2, upper_baseline_diad2, peak_pos_voigt, peak_pos_gauss, gauss_sigma, gauss_fwhm_min, gauss_amp, plot_figure, dpi, return_other_params)
#    1228 if type(peak_pos_voigt) is not float and type(peak_pos_voigt) is not np.float64 and type(peak_pos_voigt) is not int:
#    1230     if len(peak_pos_voigt)==2:
# -> 1231         axes['B'].plot(x_lin, components.get('lz2_'), '-r', linewidth=2, label='Peak2')
#    1232     if len(peak_pos_voigt)>2:
#    1233         axes['B'].plot(x_lin, components.get('lz2_'), '-r', linewidth=2, label='Peak2')
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     310     this += args[0],
#     311     args = args[1:]
# --> 312 yield from self._plot_args(this, kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:459, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     456 # Don't allow any None value; these would be up-converted to one
#     457 # element array of None which causes problems downstream.
#     458 if any(v is None for v in tup):
# --> 459     raise ValueError("x, y, and format string must not be None")
#     461 kw = {}
#     462 for prop_name, val in zip(('linestyle', 'marker', 'color'),
#     463                           (linestyle, marker, color)):
#
# ValueError: x, y, and format string must not be None

# %% [markdown]
# ## Combine and copy to clipboard!

# %%
out=pf.combine_diad_outputs(filename=filename, prefix=prefix, 
Diad1_fit=Diad1_fit, 
Diad2_fit=Diad2_fit, Carb_fit=Carb_fit)
out
# Out:
#                   filename   Splitting   Diad1_Cent    Diad1_Area  \
# 0  headless_CSV_09_K14.CSV  102.890027  1285.256419  92750.254528
#
#    Residual_Diad1   Diad2_Cent     Diad2_Area  Residual_Diad2     HB1_Cent  \
# 0      160.300544  1388.146447  142195.933212      244.644775  1264.979694
#
#       HB1_Area     HB2_Cent      HB2_Area  C13_Cent  C13_Area
# 0  8542.288503  1409.428468  11182.294974       NaN         0
