# %% [markdown]
# # 2. Filtering diad files into categories
# - This workbook shows how to filter diad files into 3 categories, to allow easier fitting
# - This data is from Devitre et al. (2021), collected from acqusitions on a high pressure optical cell on the Cornell WITec Alpha300R.

# %%
# Import useful python packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Downloading DiadFit locally
# - The easiest way to install diad fit is by removing the #. It will install from PyPI
# - You only need to do this once on each computer, or run in order to grab an updated version.

# %%
#!pip install DiadFit --upgrade

# %% [markdown]
# ### This imports DiadFit, and gives you the version. In all communication with Penny, make sure you say the version!

# %%
import DiadFit as pf
pf.__version__
# Out:
# '0.0.56'

# %% [markdown]
# ## Get the folder to your files
# - If this notebook is in the same folder as your files, you can use os. to get the file name. Else paste in the file name as DayFolder='C:/Penny' or whatever you use on your computer.
# - In this case, Spectra files are stored in one subfolder called 'Spectra', Metadata files in another subfolder called 'MetaData'

# %%
import os
DayFolder=os.getcwd()
meta_path=DayFolder +  '\MetaData'
spectra_path=DayFolder + '\Spectra'

# %% [markdown]
# ## This function finds all files in your path with the specified file format
# - Specify information about your file formats here, as well as any text in filenames that you dont want to fit.

# %%
filetype='headless_txt' # Specifies raman file format, here a text file with no header
file_ext='.txt' # File extension, a txt file
prefix=False # File doesn't have a 01, 02 prefix, as WItec can add
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'Spectrum', 'CRR'] # Exclude files with these strings in
Diad_Files=pf.get_files(path=spectra_path, file_ext=file_ext, 
            exclude_str=exclude_str)
print(Diad_Files)
# Out:
# ['Cap19-05X1.txt', 'Cap19-05X2.txt', 'Cap19-06X1.txt', 'Cap19-06X2.txt', 'Cap19-07X1.txt', 'Cap19-07X2.txt', 'Cap19-08X1.txt', 'Cap19-08X2.txt', 'Cap19-12X1.txt', 'Cap19-12X2.txt', 'Cap19-17X1.txt', 'Cap19-17X2.txt', 'Cap19-18X1.txt', 'Cap19-18X2.txt', 'FG04_31_MI.txt', 'FG04_31_MI3 (1).txt', 'FG04_31_MI3.txt', 'FG04_31_MI4 (1).txt', 'FG04_31_MI4.txt', 'POC1.txt', 'POC10.txt', 'POC11.txt', 'POC12.txt', 'POC13.txt', 'POC14.txt', 'POC15.txt', 'POC16.txt', 'POC17.txt', 'POC18.txt', 'POC19.txt', 'POC2.txt', 'POC20.txt', 'POC21.txt', 'POC22.txt', 'POC23.txt', 'POC24.txt', 'POC25.txt', 'POC26.txt', 'POC27.txt', 'POC28.txt', 'POC29.txt', 'POC3.txt', 'POC30.txt', 'POC31.txt', 'POC32.txt', 'POC33.txt', 'POC34.txt', 'POC35.txt', 'POC36.txt', 'POC37.txt', 'POC38.txt', 'POC39.txt', 'POC4.txt', 'POC40.txt', 'POC41.txt', 'POC42.txt', 'POC43.txt', 'POC44.txt', 'POC45.txt', 'POC46.txt', 'POC47.txt', 'POC48.txt', 'POC49.txt', 'POC5.txt', 'POC50.txt', 'POC51.txt', 'POC52.txt', 'POC53.txt', 'POC54.txt', 'POC55.txt', 'POC56.txt', 'POC57-0.04.txt', 'POC58.txt', 'POC6.txt', 'POC7.txt', 'POC8.txt', 'POC9.txt']

# %% [markdown]
# ## Find approximate peak positions
# - Tweak Scipy parameters to find the diad peaks
# - Tweak these parameters to make sure Scipy 'find_peaks' gets your diad peaks for your instrument.
# - Prominence: most useful parameter, required prominence of peaks
# - height: Minimum height of peaks, not that useful with various background positions
# - distance: Used to help with peaks that are very close to one another, smaller distance, remove peaks until keep set distance apart
# - width: Minimum width of peaks

# %%
# Tweak parameters away from the default here
diad_id_config=pf.diad_id_config(prominence=12, width=1)
diad_id_config
# Out:
# diad_id_config(height=1, width=1, prominence=12, plot_figure=True, exclude_range1=None, exclude_range2=None, approx_diad2_pos=(1379, 1395), approx_diad1_pos=(1275, 1290), Diad2_window=(1349, 1425), Diad1_window=(1245, 1320), approx_diad2_pos_3peaks=(1379, 1395, 1362))

# %%
# Check it has found the peaks of interest. Here we are looking at the 1st file
filetype='headless_txt'
df_peaks, Diad, fig=pf.identify_diad_peaks(
config=diad_id_config, 
path=spectra_path, filename='Cap19-07X1.txt',
filetype=filetype, plot_figure=True)
df_peaks
# Out:
#          filename  approx_split    Diad1_pos   Diad2_pos  HB1_pos  HB2_pos  \
# 2  Cap19-07X1.txt    102.753398  1286.676622  1389.43002      NaN      NaN
#
#    C13_pos  Diad1_abs_prom  Diad2_abs_prom  HB1_abs_prom  ...  HB2_height  \
# 2      NaN       45.493807       80.729699           NaN  ...         NaN
#
#    C13_height  Diad1_height  HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  \
# 2         NaN    763.793795         NaN        718.299988        719.349991
#
#    C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  \
# 2                     NaN                    NaN                        NaN
#
#    HB2_prom/std_betweendiads
# 2                        NaN
#
# [1 rows x 39 columns]

# %% [markdown]
# ### Now you have looked at a few files and are happy with these parameters, loop over all files to get approximate fit parameters for all your diad acquisitions

# %%
fit_params, data_y_all=pf.loop_approx_diad_fits(spectra_path=spectra_path, config=diad_id_config, 
                       Diad_Files=Diad_Files, filetype=filetype, plot_figure=False)
fit_params.head()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 77/77 [00:03<00:00, 22.60it/s]
# You do not have the same x axis for all spectra.
# [   1    2    3 ... 1021 1022 1023]
#          filename  approx_split    Diad1_pos    Diad2_pos      HB1_pos  \
# 0  Cap19-05X1.txt    102.879874  1286.555645  1389.435519  1266.297510
# 1  Cap19-05X2.txt    102.802888  1286.566643  1389.369532  1266.165535
# 2  Cap19-06X1.txt    102.995352  1286.121228  1389.116580  1266.022563
# 3  Cap19-06X2.txt    102.940362  1286.176218  1389.116580  1265.918082
# 4  Cap19-07X1.txt    102.753398  1286.676622  1389.430020          NaN
#
#        HB2_pos      C13_pos  Diad1_abs_prom  Diad2_abs_prom  HB1_abs_prom  \
# 0  1410.567988          NaN      222.009989      325.928941     18.617346
# 1  1410.749453  1371.321975      207.090017      314.919407     18.059665
# 2  1410.348030  1370.882059      900.938677     1506.377675     64.159427
# 3  1410.375524  1370.552122     1154.353803     1897.328891     92.969547
# 4          NaN          NaN       45.493807       80.729699           NaN
#
#    ...  HB2_height  C13_height  Diad1_height  HB1_height  Diad1_Median_Bck  \
# 0  ...  739.803160         NaN    940.310007  735.817358        718.300018
# 1  ...  776.855087  759.635352    956.390035  765.259677        749.300018
# 2  ...  816.213251  751.773108   1623.038652  783.759403        722.099976
# 3  ...  909.078730  788.882905   1911.553785  846.769534        757.199982
# 4  ...         NaN         NaN    763.793795         NaN        718.299988
#
#    Diad2_Median_Bck  C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom  \
# 0        719.250015                     NaN               0.994157
# 1        751.050003                2.772032               0.988683
# 2        723.049988                3.807857               0.997930
# 3        757.949997                6.058357               0.997362
# 4        719.349991                     NaN                    NaN
#
#    HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                  10.542742                  11.723906
# 1                   7.907439                  11.452034
# 2                  29.428163                  43.442361
# 3                  39.527512                  65.381515
# 4                        NaN                        NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Filter cosmic rays
# ### Pick a spectrum to tweak first

# %%
Diad_files=fit_params['filename']
i=5
filename_select=Diad_files.iloc[i] 
print(Diad_Files[i])
plot1=pf.plot_diad(path=spectra_path, filename=filename_select, filetype=filetype)
# Out:
# Cap19-07X2.txt

# %% [markdown]
# ### Pick your other parameters
# - NOTE that you can also change the number of neighbors considered in the intensity factor (n),but n=1 is often the best. dynfact is the intensity factor cutoff above which pixels are considered outliers in the first pass (y axis on the first plot on the leftmost). dynfact_2 is the same, but for the second pass. The filter automatically disregards pixels that are known to be of interest (here diads, hbs and c13).

# %%
# This extract the peaks for the diads, HBs and C13 from fit_params, essential to the CRR process.
diad_peaks=fit_params[['Diad1_pos','Diad2_pos','HB1_pos','HB2_pos','C13_pos']]

#Pick your settings
plot_rays='rays_only'#whether to plot the results or not
export_cleanspec=True #whether to export the spectra with the cosmic ray pixels removed
save_fig='rays_only' #whether to save the figures, options are 'all' or the default 'rays_only'
dynfact=0.0005 #dynamic intensity factor for the first pass (y axis on the leftmost plots)
dynfact_2=0.0005#dynamic intensity factor for the second pass
n=1 # number of neighboring pixels being compared, typically 1 is ideal.

# %% [markdown]
# ### Run the filter on the selected spectrum

# %%
rays_found,spectrum=pf.cosmicray_filter.filter_singleray(path=spectra_path, filetype=filetype,
Diad_files=Diad_files,i=i,diad_peaks=diad_peaks,plot_rays=plot_rays,
export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n)

#rays_found is a dataframe containing the filename and whether cosmic rays were found. spectrum is the filtered spectrum in the form of a dataframe. 
#It contains nan values where the cosmic rays are. It is NOT for fitting.

# %% [markdown]
# ### Now Loop over all other spectra
# - the output of this is the data_y_all file, which contains plottable spectra and the new fit_params file with filtered spectra

# %%
diad_peaks=fit_params[['Diad1_pos','Diad2_pos','HB1_pos','HB2_pos','C13_pos']]

data_y_all_crr,fit_params_crr=pf.cosmicray_filter.filter_raysinloop(
Diad_files=Diad_files, spectra_path=spectra_path, fit_params=fit_params, 
diad_peaks=diad_peaks,plot_rays=plot_rays,
export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n)
# Out:
#  84%|████████████████████████████████████████████████████████████████████████████████▏              | 65/77 [00:04<00:00, 17.84it/s]g:\my drive\berkeley_new\diadfit_outer\src\DiadFit\cosmicray_filter.py:225: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, (ax0,ax1,ax2,ax3,ax4) = plt.subplots(1,5,figsize=figsize)
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 77/77 [00:05<00:00, 13.83it/s]
#                      filename rays_present  approx_split    Diad1_pos  \
# 0  Cap19-05X1_CRR_DiadFit.txt         True    102.879874  1286.555645
# 1  Cap19-05X2_CRR_DiadFit.txt         True    102.802888  1286.566643
# 2              Cap19-06X1.txt        False    102.995352  1286.121228
# 3              Cap19-06X2.txt        False    102.940362  1286.176218
# 4              Cap19-07X1.txt        False    102.753398  1286.676622
#
#      Diad2_pos      HB1_pos      HB2_pos      C13_pos  Diad1_abs_prom  \
# 0  1389.435519  1266.297510  1410.567988          NaN      222.009989
# 1  1389.369532  1266.165535  1410.749453  1371.321975      207.090017
# 2  1389.116580  1266.022563  1410.348030  1370.882059      900.938677
# 3  1389.116580  1265.918082  1410.375524  1370.552122     1154.353803
# 4  1389.430020          NaN          NaN          NaN       45.493807
#
#    Diad2_abs_prom  ...  HB2_height  C13_height  Diad1_height  HB1_height  \
# 0      325.928941  ...  739.803160         NaN    940.310007  735.817358
# 1      314.919407  ...  776.855087  759.635352    956.390035  765.259677
# 2     1506.377675  ...  816.213251  751.773108   1623.038652  783.759403
# 3     1897.328891  ...  909.078730  788.882905   1911.553785  846.769534
# 4       80.729699  ...         NaN         NaN    763.793795         NaN
#
#    Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0        718.300018        719.250015                     NaN
# 1        749.300018        751.050003                2.772032
# 2        722.099976        723.049988                3.807857
# 3        757.199982        757.949997                6.058357
# 4        718.299988        719.349991                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0               0.994157                  10.542742                  11.723906
# 1               0.988683                   7.907439                  11.452034
# 2               0.997930                  29.428163                  43.442361
# 3               0.997362                  39.527512                  65.381515
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Plot peak parameters
# - This will help you inspect clear cut offs you can use to split your diads into groups for fitting
# - You can enter different x and y coordinates from the dataframe headings above

# %%
fig=pf.plot_peak_params(fit_params=fit_params_crr, 
                     x_param='Diad1_pos',  y1_param='approx_split',
                    y2_param='Diad1_abs_prom', y3_param='C13_abs_prom',
                    y4_param='Diad1_prom/std_betweendiads', fill_na=-1000)

# %% [markdown]
# ### Filter out ones with really bad splitting or really low diad prominence
# - Here, we only take files with splitting between 101-108 (you will need to tweak this for each instrument)
# - We also only take files with a prominence of diad 1 >10
# - None here got filtered out, but these can be helpful filters on other datasets

# %%
fit_params_filt, data_y_filt, fit_params_disc, data_y_disc=pf.filter_splitting_prominence(
fit_params=fit_params_crr, data_y_all=data_y_all_crr, x_cord=Diad[:, 0],
splitting_limits=[101, 108], lower_diad1_prom=10)
# Out:
# Keeping N=77
# Discarding N=0

# %% [markdown]
# ### Now apply filters to find the weakest diads (e.g. ones you wouldnt want to fit a hotband too)
# - In this case, we find the best filters are the position of Diad1 (shifts way more than Diad2),
# and where HB2 had a prominence (e.g., not nan because it wasnt found)
# - We find it also helpful to apply a filter, e.g. weak is Diad1pos<1287 or HB2 prominence nan, and  the prominence of Diad1 is <300X the standard deviation of the diad region

# %%
type(filter_bool)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22492\1065904926.py in <module>
# ----> 1 type(filter_bool)
#
# NameError: name 'filter_bool' is not defined

# %%
Filter1=fit_params_crr['Diad1_pos']<1287.5
Filter2=np.isnan(fit_params_crr['HB2_abs_prom'])
Filter3=fit_params_crr['Diad1_prom/std_betweendiads']<100
# Spectra shown on the left meet this criteria
filter_bool=(Filter1|Filter2)&Filter3
fit_params_Weak, fit_params_NotWeak, data_y_Weak, data_y_NotWeak=pf.identify_diad_group(
    fit_params=fit_params_filt, 
     data_y=data_y_filt, 
    x_cord=Diad[:, 0], 
      filter_bool=filter_bool, grp_filter='Weak')

# %% [markdown]
# ## Seperate Medium and strong diads
# - Now we need to find something that separates out strong diads from medium strength diads
# - The aim here is to get diads that are sufficiently strong that you have to fit a gaussian background in addition to diads, hbs and C13 peaks. Not having to fit a gaussian background to medium density diads will save you a lot of computational time (and decrease the number of bad fits)
# - In many datasets, you wont need a strong diad category. In which case, everything will stay in the 'Medium' Category
# - Here, the best filter appears to be the prominence of the C13 peak, and the general elevation of the valley between diad and HB above the background outside the diad positions (Mean_Diad_HB variable).

# %%
var1='Av_Diad_prom/std_betweendiads'
var2='Mean_Diad_HB_Valley_prom'
filter_bool_Strong=(fit_params_NotWeak[var2]>1.01)|(fit_params_NotWeak[var1]>1000)

# ((fit_params_NotWeak[var1]>100)
                   # &(fit_params_NotWeak[var2]>100))
# Here we make a plot of these parameters to better help select the right values
fig, (ax1) = plt.subplots(1, 1, figsize=(7,4))
ax1.plot(fit_params_NotWeak[var1].loc[filter_bool_Strong],
         fit_params_NotWeak[var2].loc[filter_bool_Strong], 'xr', label='Strong')
ax1.plot(fit_params_NotWeak[var1].loc[~filter_bool_Strong],
         fit_params_NotWeak[var2].loc[~filter_bool_Strong], 'xk', label='Medium')
ax1.set_yscale('log')
ax1.set_xscale('log')
ax1.set_xlabel(var1)
ax1.set_ylabel(var2)
ax1.legend()

#This makes a plot
fit_params_Strong, fit_params_Medium, data_y_Strong, data_y_Medium=pf.identify_diad_group(
    fit_params=fit_params_NotWeak.reset_index(drop=True), 
    data_y=data_y_NotWeak,x_cord=Diad[:, 0], 
    filter_bool=filter_bool_Strong, y_fig_scale=0.1, grp_filter='Medium-Strong')

# %% [markdown]
# ## Plot them all

# %%
fig=pf.plot_diad_groups( x_cord=Diad[:, 0], Weak_np=data_y_Weak,
                 Medium_np=data_y_Medium, Strong_np=data_y_Strong,
                       y_fig_scale=0.1)
fig.savefig('Diad_Groups.png', dpi=300)

# %% [markdown]
# ## Now lets save these lists, and we load them in another notebook

# %%
import joblib
joblib.dump(Diad[:, 0], 'np_x.sav')
joblib.dump(fit_params_Weak.reset_index(drop=True), 'Weak_df.sav')
joblib.dump(fit_params_Medium.reset_index(drop=True), 'Medium_df.sav')
joblib.dump(fit_params_Strong.reset_index(drop=True), 'Strong_df.sav')
fit_params_disc.to_excel('Discarded_df.xlsx')

# %%
fit_params_Medium
# Out:
#                       filename rays_present  approx_split    Diad1_pos  \
# 0   Cap19-05X1_CRR_DiadFit.txt         True    102.879874  1286.555645
# 1               Cap19-06X1.txt        False    102.995352  1286.121228
# 2               Cap19-06X2.txt        False    102.940362  1286.176218
# 3   Cap19-08X1_CRR_DiadFit.txt         True    102.797389  1286.506155
# 4               Cap19-08X2.txt        False    102.797389  1286.533650
# 5               Cap19-12X1.txt        False    102.995352  1286.093734
# 6               Cap19-12X2.txt        False    102.956859  1286.137725
# 7               Cap19-17X1.txt        False    102.791890  1286.346685
# 8   Cap19-17X2_CRR_DiadFit.txt         True    102.824884  1286.473161
# 9               Cap19-18X1.txt        False    102.890872  1286.203713
# 10              Cap19-18X2.txt        False    102.846880  1286.385178
# 11             FG04_31_MI3.txt        False    103.209811  1285.318382
# 12             FG04_31_MI4.txt        False    103.413272  1284.911459
# 13       POC39_CRR_DiadFit.txt         True    102.797389  1286.484159
# 14       POC40_CRR_DiadFit.txt         True    102.819385  1286.500656
# 15                   POC41.txt        False    102.780893  1286.522652
# 16                   POC42.txt        False    102.791890  1286.544648
# 17                   POC43.txt        False    102.791890  1286.555645
# 18                   POC44.txt        False    102.797389  1286.561144
# 19                   POC45.txt        False    102.786392  1286.577641
# 20                   POC46.txt        False    102.786392  1286.594138
# 21                   POC47.txt        False    102.786392  1286.599637
# 22                   POC48.txt        False    102.797389  1286.610635
# 23                   POC49.txt        False    102.775394  1286.621633
# 24                   POC50.txt        False    102.736901  1286.671123
#
#       Diad2_pos      HB1_pos      HB2_pos      C13_pos  Diad1_abs_prom  \
# 0   1389.435519  1266.297510  1410.567988          NaN      222.009989
# 1   1389.116580  1266.022563  1410.348030  1370.882059      900.938677
# 2   1389.116580  1265.918082  1410.375524  1370.552122     1154.353803
# 3   1389.303544  1266.682437  1410.655971          NaN      218.255766
# 4   1389.331039  1266.314007  1410.540493          NaN      210.745139
# 5   1389.089085  1265.852095  1410.359028  1370.981040      879.619341
# 6   1389.094584  1265.874091  1410.392021  1370.942547      522.187868
# 7   1389.138576  1265.995068  1410.441512          NaN      239.890092
# 8   1389.298045  1266.242521  1410.491002  1371.547432      447.446825
# 9   1389.094584  1265.907085  1410.386522  1370.843566      651.749407
# 10  1389.232058  1266.171034  1410.573487  1370.931549      694.659247
# 11  1388.528192  1265.357189  1409.880619  1370.409149     1307.209751
# 12  1388.324731  1265.247210  1409.787137  1370.398151      549.852234
# 13  1389.281549  1266.198529  1410.529495  1370.909553     2010.201116
# 14  1389.320041  1266.281013  1410.540493  1370.986539     1854.431311
# 15  1389.303544  1266.292011  1410.606480  1371.030530     1569.326731
# 16  1389.336538  1266.303009  1410.589984  1371.036029     1294.977795
# 17  1389.347536  1266.303009  1410.556990  1371.063524     1076.040515
# 18  1389.358534  1266.303009  1410.611979  1371.030530     1010.969257
# 19  1389.364033  1266.314007  1410.584485  1371.058025      855.920568
# 20  1389.380530  1266.270015  1410.622977  1371.030530      736.787953
# 21  1389.386029  1266.325005  1410.584485  1370.662101      632.340574
# 22  1389.408024  1266.363498  1410.655971  1371.058025      503.108762
# 23  1389.397027  1266.325005  1410.556990  1371.063524      362.728359
# 24  1389.408024  1266.363498  1410.798944          NaN      249.280508
#
#     Diad2_abs_prom  ...  Av_Diad_HB_prom_ratio  Diad2_height   HB2_height  \
# 0       325.928941  ...              13.833931   1045.178957   739.803160
# 1      1506.377675  ...              14.973400   2229.427663   816.213251
# 2      1897.328891  ...              12.377259   2655.278888   909.078730
# 3       313.908041  ...              14.768000   1019.308035   732.735487
# 4       316.550958  ...              10.842781   1053.000955   767.022796
# 5      1458.538732  ...              14.575781   2174.488729   813.600579
# 6       880.088990  ...              12.535532   1616.788971   802.293574
# 7       367.940269  ...              14.185888   1093.590248   749.583625
# 8       666.389413  ...              11.537757   1417.489419   808.382720
# 9      1050.321815  ...              14.783351   1773.121803   792.849329
# 10     1068.380151  ...              12.270246   1851.830148   869.183095
# 11     2599.305057  ...               9.474232   3341.055042   998.982076
# 12     1091.387999  ...              14.677564   1800.337996   776.102041
# 13     3067.749251  ...              11.805015   3794.499235  1003.288907
# 14     2815.375543  ...              11.319337   3540.208856   987.425109
# 15     2411.356762  ...              11.521026   3135.023418   935.815793
# 16     1995.800943  ...              11.563014   2717.200968   904.290736
# 17     1677.372608  ...              11.308912   2396.772602   874.311616
# 18     1536.391991  ...              11.324289   2255.291985   853.858667
# 19     1338.860067  ...              11.405144   2056.410070   840.395984
# 20     1143.084949  ...              11.435806   1859.684955   819.726362
# 21      978.210364  ...              12.175761   1693.860374   801.746498
# 22      766.509264  ...              12.704285   1482.509264   785.688812
# 23      559.559582  ...              12.533405   1275.809567   767.760193
# 24      390.374413  ...              11.497877   1105.074425   753.027500
#
#     C13_height  Diad1_height  HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  \
# 0          NaN    940.310007  735.817358        718.300018        719.250015
# 1   751.773108   1623.038652  783.759403        722.099976        723.049988
# 2   788.882905   1911.553785  846.769534        757.199982        757.949997
# 3          NaN    923.655760  717.234493        705.399994        705.399994
# 4          NaN    946.645133  752.799857        735.899994        736.449997
# 5   737.205500   1594.819353  774.267559        715.200012        715.949997
# 6   753.696441   1259.087862  778.601848        736.899994        736.699982
# 7          NaN    964.490067  742.101102        724.599976        725.649979
# 8   760.814645   1197.046831  786.030931        749.600006        751.100006
# 9   739.379359   1373.749407  763.962237        722.000000        722.799988
# 10  801.755906   1477.559241  835.970076        782.899994        783.449997
# 11  801.185755   2051.809727  884.159930        744.599976        741.749985
# 12  733.970608   1260.152221  750.414326        710.299988        708.949997
# 13  775.697420   2738.201116  884.468363        728.000000        726.749985
# 14  766.673087   2580.931311  879.967400        726.500000        724.833313
# 15  756.779710   2294.326731  856.471158        725.000000        723.666657
# 16  752.718365   2017.977795  827.613469        723.000000        721.400024
# 17  746.443793   1797.240497  812.428261        721.199982        719.399994
# 18  740.245356   1731.469257  810.021590        720.500000        718.899994
# 19  738.440809   1575.220556  790.999847        719.299988        717.550003
# 20  734.656287   1455.587972  782.257727        718.800018        716.600006
# 21  725.524234   1349.940580  767.411252        717.600006        715.650009
# 22  728.349401   1221.008786  754.163549        717.900024        716.000000
# 23  723.672668   1081.028347  745.406409        718.299988        716.249985
# 24         NaN    966.180502  738.139618        716.899994        714.700012
#
#     C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom
# 0                      NaN               0.994157
# 1                 3.807857               0.997930
# 2                 6.058357               0.997362
# 3                      NaN               0.994063
# 4                      NaN               0.994964
# 5                 5.315666               1.001259
# 6                 4.892099               0.995382
# 7                      NaN               0.993934
# 8                 5.312373               0.990173
# 9                 4.573314               0.998338
# 10                4.932993               0.993605
# 11                5.793084               1.010515
# 12                3.618239               1.007060
# 13                6.243798               0.992671
# 14                7.067908               0.994265
# 15                7.254091               0.996537
# 16                6.415724               0.997921
# 17                5.925930               0.993339
# 18                6.654744               0.992900
# 19                6.586554               0.995541
# 20                6.432566               0.995394
# 21                8.910356               0.995805
# 22                5.097594               0.994691
# 23                8.830801               0.994968
# 24                     NaN               0.993984
#
# [25 rows x 41 columns]
