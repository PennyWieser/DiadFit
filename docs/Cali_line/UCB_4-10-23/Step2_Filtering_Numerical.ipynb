# %% [markdown]
# # 2. Filtering diad files into categories
# - This workbook shows how to filter diad files into 3 categories, to allow easier fitting
# - This data is from Devitre et al. (2021), collected from acqusitions on a high pressure optical cell on the Cornell WITec Alpha300R.

# %%
# Import useful python packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Downloading DiadFit locally
# - The easiest way to install diad fit is by removing the #. It will install from PyPI
# - You only need to do this once on each computer, or run in order to grab an updated version.

# %%
#!pip install DiadFit --upgrade

# %% [markdown]
# ### This imports DiadFit, and gives you the version. In all communication with Penny, make sure you say the version!

# %%
import DiadFit as pf
pf.__version__
# Out:
# '0.0.58'

# %% [markdown]
# ## Get the folder to your files
# - If this notebook is in the same folder as your files, you can use os. to get the file name. Else paste in the file name as DayFolder='C:/Penny' or whatever you use on your computer.
# - In this case, Spectra files are stored in one subfolder called 'Spectra', Metadata files in another subfolder called 'MetaData'

# %%
import os
DayFolder=os.getcwd()
meta_path=DayFolder +  '\METADATA'
spectra_path=DayFolder + '\SPECTRA'

# %% [markdown]
# ## This function finds all files in your path with the specified file format
# - Specify information about your file formats here, as well as any text in filenames that you dont want to fit.

# %%
filetype='headless_txt' # Specifies raman file format, here a text file with no header
file_ext='.txt' # File extension, a txt file
prefix=False # File doesn't have a 01, 02 prefix, as WItec can add
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'Spectrum', 'CRR'] # Exclude files with these strings in
Diad_Files=pf.get_files(path=spectra_path, file_ext=file_ext, exclude_str=exclude_str)
print(Diad_Files)
# Out:
# ['FDCA-P1-1.txt', 'FDCA-P1-2.txt', 'FDCA-P1-3.txt', 'FDCA-P10-1.txt', 'FDCA-P10-2.txt', 'FDCA-P10-3.txt', 'FDCA-P11-1.txt', 'FDCA-P12-1.txt', 'FDCA-P13-1.txt', 'FDCA-P14-1.txt', 'FDCA-P14-2.txt', 'FDCA-P14-3.txt', 'FDCA-P15-1.txt', 'FDCA-P16-1.txt', 'FDCA-P17-1.txt', 'FDCA-P18-1.txt', 'FDCA-P18-2.txt', 'FDCA-P19-1.txt', 'FDCA-P19-2.txt', 'FDCA-P19-3.txt', 'FDCA-P2-1.txt', 'FDCA-P2-2.txt', 'FDCA-P2-3.txt', 'FDCA-P20-1.txt', 'FDCA-P21-1.txt', 'FDCA-P22-1.txt', 'FDCA-P23-1.txt', 'FDCA-P23-2.txt', 'FDCA-P23-3.txt', 'FDCA-P24-1.txt', 'FDCA-P25-1.txt', 'FDCA-P26-1.txt', 'FDCA-P26-2.txt', 'FDCA-P27-1.txt', 'FDCA-P27-2.txt', 'FDCA-P27-3.txt', 'FDCA-P28-1.txt', 'FDCA-P29-1.txt', 'FDCA-P3-1.txt', 'FDCA-P3-2.txt', 'FDCA-P3-3.txt', 'FDCA-P30-1.txt', 'FDCA-P31-1.txt', 'FDCA-P31-2.txt', 'FDCA-P31-3.txt', 'FDCA-P32-1.txt', 'FDCA-P33-1.txt', 'FDCA-P34-1.txt', 'FDCA-P35-1.txt', 'FDCA-P35-2.txt', 'FDCA-P35-3.txt', 'FDCA-P36-1.txt', 'FDCA-P36-2.txt', 'FDCA-P36-3.txt', 'FDCA-P37-1.txt', 'FDCA-P38-1.txt', 'FDCA-P39-1.txt', 'FDCA-P39-2.txt', 'FDCA-P39-3.txt', 'FDCA-P4-1.txt', 'FDCA-P4-2.txt', 'FDCA-P4-3.txt', 'FDCA-P40-1.txt', 'FDCA-P40-2.txt', 'FDCA-P42-1.txt', 'FDCA-P43-1.txt', 'FDCA-P43-2.txt', 'FDCA-P43-3.txt', 'FDCA-P44-1.txt', 'FDCA-P45-1.txt', 'FDCA-P46-1.txt', 'FDCA-P47-1.txt', 'FDCA-P48-1.txt', 'FDCA-P48-2.txt', 'FDCA-P48-3.txt', 'FDCA-P49-1.txt', 'FDCA-P5-1.txt', 'FDCA-P5-2.txt', 'FDCA-P5-3.txt', 'FDCA-P50-1.txt', 'FDCA-P51-1.txt', 'FDCA-P52-1.txt', 'FDCA-P52-2.txt', 'FDCA-P52-3.txt', 'FDCA-P53-1.txt', 'FDCA-P54-1.txt', 'FDCA-P55-1.txt', 'FDCA-P56-1.txt', 'FDCA-P56-2.txt', 'FDCA-P56-3.txt', 'FDCA-P57-2.txt', 'FDCA-P58-1.txt', 'FDCA-P59-1.txt', 'FDCA-P6-1.txt', 'FDCA-P6-2.txt', 'FDCA-P6-3.txt', 'FDCA-P60-1.txt', 'FDCA-P60-2.txt', 'FDCA-P60-3.txt', 'FDCA-P61-1.txt', 'FDCA-P61-2.txt', 'FDCA-P61-3.txt', 'FDCA-P62-1.txt', 'FDCA-P62-2.txt', 'FDCA-P62-3.txt', 'FDCA-P63-1.txt', 'FDCA-P63-2.txt', 'FDCA-P63-3.txt', 'FDCA-P64-1.txt', 'FDCA-P64-2.txt', 'FDCA-P64-3.txt', 'FDCA-P65-1.txt', 'FDCA-P65-2.txt', 'FDCA-P65-3.txt', 'FDCA-P66-1.txt', 'FDCA-P66-2.txt', 'FDCA-P66-3.txt', 'FDCA-P67-1.txt', 'FDCA-P67-2.txt', 'FDCA-P67-3.txt', 'FDCA-P68-1.txt', 'FDCA-P68-2.txt', 'FDCA-P68-3.txt', 'FDCA-P69-1.txt', 'FDCA-P69-2.txt', 'FDCA-P69-3.txt', 'FDCA-P7-1.txt', 'FDCA-P7-2.txt', 'FDCA-P7-3.txt', 'FDCA-P70-1.txt', 'FDCA-P70-2.txt', 'FDCA-P70-3.txt', 'FDCA-P71-1.txt', 'FDCA-P71-2.txt', 'FDCA-P71-3.txt', 'FDCA-P72-1.txt', 'FDCA-P72-2.txt', 'FDCA-P72-3.txt', 'FDCA-P73-1.txt', 'FDCA-P73-2.txt', 'FDCA-P73-3.txt', 'FDCA-P74-1.txt', 'FDCA-P74-2.txt', 'FDCA-P74-3.txt', 'FDCA-P75-1.txt', 'FDCA-P75-2.txt', 'FDCA-P75-3.txt', 'FDCA-P76-1.txt', 'FDCA-P76-2.txt', 'FDCA-P76-3.txt', 'FDCA-P8-1.txt', 'FDCA-P8-2.txt', 'FDCA-P8-3.txt', 'FDCA-P9-1.txt', 'FDCA-P9-2.txt', 'FDCA-P9-3.txt']

# %%
len(Diad_Files)
# Out:
# 156

# %% [markdown]
# ## Lets check for duplicates - this will cause matching issues if you have named a set file the same thing
# - if you have duplicates, go into your file structure now and sort out the names for the metadata and spectra files

# %%
spectra_dup_Check=pf.extracting_filenames_generic(names=pd.Series(Diad_Files),
    prefix=False, str_prefix=" ",
   file_type='.txt')
# Out:
# good job, no duplicate file names

# %% [markdown]
# ## Lets save all these files to excel so you hvae somewhere to take notes on anything you want/the FI that will get merged with the data later
# - This is where you can note things about the spectral fits too/

# %%
df=pd.DataFrame(data={'Spectral Name': Diad_Files, 'To use': '','Diad1_Fit':'' ,'Diad2_Fit':'','FI diameter':'', 'Textural context':'',
'Additional Notes': ''})
# Save the DataFrame to an Excel file
if not os.path.exists("Names_for_notes.xlsx"):
    df.to_excel("Names_for_notes.xlsx", index=False)

# %% [markdown]
# ## Find approximate peak positions
# - Tweak Scipy parameters to find the diad peaks
# - Tweak these parameters to make sure Scipy 'find_peaks' gets your diad peaks for your instrument.
# - Prominence: most useful parameter, required prominence of peaks
# - height: Minimum height of peaks, not that useful with various background positions
# - distance: Used to help with peaks that are very close to one another, smaller distance, remove peaks until keep set distance apart
# - width: Minimum width of peaks

# %%
# Tweak parameters away from the default here
diad_id_config=pf.diad_id_config(prominence=50, width=1)
diad_id_config
# Out:
# diad_id_config(height=1, width=1, prominence=50, plot_figure=True, exclude_range1=None, exclude_range2=None, approx_diad2_pos=(1379, 1395), approx_diad1_pos=(1275, 1290), Diad2_window=(1349, 1425), Diad1_window=(1245, 1320), approx_diad2_pos_3peaks=(1379, 1395, 1362))

# %%
# Check it has found the peaks of interest. Here we are looking at the 1st file
filetype='headless_txt'
df_peaks, Diad, fig=pf.identify_diad_peaks(
config=diad_id_config, 
path=spectra_path, filename=Diad_Files[0],
filetype=filetype, plot_figure=True)
df_peaks
# Out:
#         filename  approx_split    Diad1_pos   Diad2_pos      HB1_pos  \
# 3  FDCA-P1-1.txt    105.570637  1280.778152  1386.34879  1260.512065
#
#        HB2_pos      C13_pos  Diad1_abs_prom  Diad2_abs_prom  HB1_abs_prom  \
# 3  1407.659803  1369.217484     4847.457414     9482.707955    220.610325
#
#    ...   HB2_height  C13_height  Diad1_height  HB1_height  Diad1_Median_Bck  \
# 3  ...  1040.431258  963.903522   5573.657426  919.010349        726.200012
#
#    Diad2_Median_Bck  C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom  \
# 3        728.100006                 2.25332               1.183347
#
#    HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 3                  65.142963                   99.87468
#
# [1 rows x 39 columns]

# %% [markdown]
# ### Now you have looked at a few files and are happy with these parameters, loop over all files to get approximate fit parameters for all your diad acquisitions

# %%
fit_params, data_y_all=pf.loop_approx_diad_fits(spectra_path=spectra_path, config=diad_id_config, 
                       Diad_Files=Diad_Files, filetype=filetype, plot_figure=False)
fit_params.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 156/156 [00:10<00:00, 15.51it/s]
#          filename  approx_split    Diad1_pos   Diad2_pos      HB1_pos  \
# 0   FDCA-P1-1.txt    105.570637  1280.778152  1386.34879  1260.512065
# 1   FDCA-P1-2.txt    105.576137  1280.772653  1386.34879  1260.127092
# 2   FDCA-P1-3.txt    105.576137  1280.767153  1386.34329  1260.550563
# 3  FDCA-P10-1.txt    105.147167  1281.339113  1386.48628  1260.853042
# 4  FDCA-P10-2.txt    105.158166  1281.333613  1386.49178  1261.479998
#
#        HB2_pos      C13_pos  Diad1_abs_prom  Diad2_abs_prom  HB1_abs_prom  \
# 0  1407.659803  1369.217484     4847.457414     9482.707955    220.610325
# 1  1407.687301  1369.255982     5083.317217     9889.857815    220.225236
# 2  1408.050276  1369.134990     4766.794313     9232.841715    210.575614
# 3  1407.984281  1369.123991     5225.687184    10072.836657    234.964139
# 4  1407.830291  1369.129490     5560.817810    10777.556779    258.735171
#
#    ...   HB2_height  C13_height  Diad1_height  HB1_height  Diad1_Median_Bck  \
# 0  ...  1040.431258  963.903522   5573.657426  919.010349        726.200012
# 1  ...  1059.938968  972.331543   5808.817217  916.425249        725.500000
# 2  ...  1044.114609  955.661146   5491.994325  906.975638        725.200012
# 3  ...  1086.902428  958.276249   5940.987172  922.964139        715.299988
# 4  ...  1123.947027  984.270881   6280.817810  949.735171        720.000000
#
#    Diad2_Median_Bck  C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom  \
# 0        728.100006                2.253320               1.183347
# 1        727.799988                2.396952               1.182645
# 2        727.949997                2.398794               1.170953
# 3        717.449982                2.478250               1.162436
# 4        722.449997                2.470392               1.172328
#
#    HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                  65.142963                  99.874680
# 1                  65.252712                 106.412839
# 2                  60.246187                  97.908421
# 3                  92.393164                 155.166521
# 4                 113.796863                 188.263579
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Filter out spectra with Cosmic rays

# %% [markdown]
# ### Pick a spectra to tweak first

# %%
Diad_files=fit_params['filename']
i=0
filename_select=Diad_files.iloc[i] 
print(Diad_Files[i])
plot1=pf.plot_diad(path=spectra_path, filename=filename_select, filetype=filetype)
# Out:
# FDCA-P1-1.txt

# %% [markdown]
# ### Pick your other parameters
#
# NOTE that you can also change the number of neighbors considered in the intensity factor (n),but n=1 is often the best. dynfact is the intensity factor cutoff above which pixels are considered outliers in the first pass (y axis on the first plot on the leftmost). dynfact_2 is the same, but for the second pass. The filter automatically disregards pixels that are known to be of interest (here diads, hbs and c13).

# %%
# This extract the peaks for the diads, HBs and C13 from fit_params_crr, essential to the CRR process.
diad_peaks=fit_params[['Diad1_pos','Diad2_pos','HB1_pos','HB2_pos','C13_pos']]

#Pick your settings
plot_rays='rays_only'#whether to plot the results or not
export_cleanspec=True #whether to export the spectra with the cosmic ray pixels removed
save_fig='all' #whether to save the figures, options are 'all' or the default 'rays_only'
dynfact=0.005 #dynamic intensity factor for the first pass (y axis on the leftmost plots)
dynfact_2=0.001#dynamic intensity factor for the second pass
n=1 # number of neighboring pixels being compared, typically 1 is ideal.

exclude_ranges=[(1100,1200)] # List of tuples containing ranges to exclude from filtering (i.e., for secondary peaks

# %% [markdown]
# ### Run the filter on the selected spectra
# - rays_found is a dataframe containing the filename and whether cosmic rays were found. spectrum is the filtered spectrum in the form of a dataframe.
# - It contains nan values where the cosmic rays are. It is NOT for fitting.

# %%
rays_found,spectrum=pf.cosmicray_filter.filter_singleray(path=spectra_path,
                                        exclude_ranges=exclude_ranges,filetype=filetype,
                                        Diad_files=Diad_files,i=i,diad_peaks=diad_peaks,plot_rays=plot_rays,
                                      export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n, filetype=filetype)

# %% [markdown]
# ###  Loop over all other spectra
# the output of this is the data_y_all file, which contains plottable spectra and the new fit_params file with filtered spectra

# %%
data_y_all_crr,fit_params_crr=pf.cosmicray_filter.filter_raysinloop(Diad_files=Diad_files,
spectra_path=spectra_path, exclude_ranges=exclude_ranges,
fit_params=fit_params, diad_peaks=diad_peaks,plot_rays=plot_rays,
export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n, filetype=filetype)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 156/156 [00:10<00:00, 15.04it/s]
#          filename rays_present  approx_split    Diad1_pos   Diad2_pos  \
# 0   FDCA-P1-1.txt        False    105.570637  1280.778152  1386.34879
# 1   FDCA-P1-2.txt        False    105.576137  1280.772653  1386.34879
# 2   FDCA-P1-3.txt        False    105.576137  1280.767153  1386.34329
# 3  FDCA-P10-1.txt        False    105.147167  1281.339113  1386.48628
# 4  FDCA-P10-2.txt        False    105.158166  1281.333613  1386.49178
#
#        HB1_pos      HB2_pos      C13_pos  Diad1_abs_prom  Diad2_abs_prom  ...  \
# 0  1260.512065  1407.659803  1369.217484     4847.457414     9482.707955  ...
# 1  1260.127092  1407.687301  1369.255982     5083.317217     9889.857815  ...
# 2  1260.550563  1408.050276  1369.134990     4766.794313     9232.841715  ...
# 3  1260.853042  1407.984281  1369.123991     5225.687184    10072.836657  ...
# 4  1261.479998  1407.830291  1369.129490     5560.817810    10777.556779  ...
#
#     HB2_height  C13_height  Diad1_height  HB1_height  Diad1_Median_Bck  \
# 0  1040.431258  963.903522   5573.657426  919.010349        726.200012
# 1  1059.938968  972.331543   5808.817217  916.425249        725.500000
# 2  1044.114609  955.661146   5491.994325  906.975638        725.200012
# 3  1086.902428  958.276249   5940.987172  922.964139        715.299988
# 4  1123.947027  984.270881   6280.817810  949.735171        720.000000
#
#    Diad2_Median_Bck  C13_HB2_abs_prom_ratio  Diad2_HB2_Valley_prom  \
# 0        728.100006                2.253320               1.183347
# 1        727.799988                2.396952               1.182645
# 2        727.949997                2.398794               1.170953
# 3        717.449982                2.478250               1.162436
# 4        722.449997                2.470392               1.172328
#
#    HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                  65.142963                  99.874680
# 1                  65.252712                 106.412839
# 2                  60.246187                  97.908421
# 3                  92.393164                 155.166521
# 4                 113.796863                 188.263579
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Plot peak parameters
# - This will help you inspect clear cut offs you can use to split your diads into groups for fitting
# - You can enter different x and y coordinates from the dataframe headings above

# %%
fig=pf.plot_peak_params(fit_params=fit_params_crr, 
                     x_param='Diad1_pos',  y1_param='approx_split',
                    y2_param='Diad1_abs_prom', y3_param='C13_abs_prom',
                    y4_param='Diad1_prom/std_betweendiads', fill_na=-1000)

# %% [markdown]
# ### Filter out ones with really bad splitting or really low diad prominence
# - Here, we only take files with splitting between 101-108 (you will need to tweak this for each instrument)
# - We also only take files with a prominence of diad 1 >10
# - None here got filtered out, but these can be helpful filters on other datasets

# %%
fit_params_filt, data_y_filt, fit_params_disc, data_y_disc=pf.filter_splitting_prominence(
fit_params=fit_params_crr, data_y_all=data_y_all, x_cord=Diad[:, 0],
splitting_limits=[101, 108], lower_diad1_prom=10)
# Out:
# Keeping N=156
# Discarding N=0

# %% [markdown]
# ### Now apply filters to find the weakest diads (e.g. ones you wouldnt want to fit a hotband too)
# - In this case, we find the best filters are the position of Diad1 (shifts way more than Diad2),
# and where HB2 had a prominence (e.g., not nan because it wasnt found)
# - We find it also helpful to apply a filter, e.g. weak is Diad1pos<1287 or HB2 prominence nan, and  the prominence of Diad1 is <300X the standard deviation of the diad region

# %%
fit_params.columns
# Out:
# Index(['filename', 'approx_split', 'Diad1_pos', 'Diad2_pos', 'HB1_pos',
#        'HB2_pos', 'C13_pos', 'Diad1_abs_prom', 'Diad2_abs_prom',
#        'HB1_abs_prom', 'HB2_abs_prom', 'C13_abs_prom', 'Mean_abs_HB_prom',
#        'Diad2_HB2_abs_prom_ratio', 'Diad1_HB1_abs_prom_ratio',
#        'Diad1_rel_prom', 'Diad2_rel_prom', 'HB1_rel_prom', 'HB2_rel_prom',
#        'C13_rel_prom', 'Diad1_HB1_Valley_prom', 'Mean_Diad_HB_Valley_prom',
#        'Diad1_prom/std_betweendiads', 'Diad2_prom/std_betweendiads',
#        'Av_Diad_prom/std_betweendiads', 'C13_prom/HB2_prom',
#        'Av_Diad_HB_prom_ratio', 'Left_vs_Right', 'Diad2_height', 'HB2_height',
#        'C13_height', 'Diad1_height', 'HB1_height', 'Diad1_Median_Bck',
#        'Diad2_Median_Bck', 'C13_HB2_abs_prom_ratio', 'Diad2_HB2_Valley_prom',
#        'HB1_prom/std_betweendiads', 'HB2_prom/std_betweendiads'],
#       dtype='object')

# %%
param_1='Left_vs_Right'
param_2='Diad1_prom/std_betweendiads'
param_3='Diad1_pos'
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10,5))
ax1.hist(fit_params[param_1])
ax1.set_xlabel(param_1)
ax2.hist(fit_params[param_2])
ax2.set_xlabel(param_2)
ax3.hist(fit_params[param_3])
ax3.set_xlabel(param_3)
# Out:
# Text(0.5, 0, 'Diad1_pos')

# %%
Filter1=fit_params_filt['Diad1_pos']>1285
Filter2=(fit_params_filt['Left_vs_Right']<0.89)
Filter3=fit_params_filt['Diad1_prom/std_betweendiads']<150

filter_bool=(Filter1&Filter3)|Filter2
fit_params_Weak, fit_params_NotWeak, data_y_Weak, data_y_NotWeak=pf.identify_diad_group(
    fit_params=fit_params_filt, 
     data_y=data_y_filt, 
    x_cord=Diad[:, 0], 
    y_fig_scale=0.5,
    filter_bool=filter_bool, grp_filter='Weak')

# %% [markdown]
# ## Seperate Medium and strong diads
# - Now we need to find something that separates out strong diads from medium strength diads
# - The aim here is to get diads that are sufficiently strong that you have to fit a gaussian background in addition to diads, hbs and C13 peaks. Not having to fit a gaussian background to medium density diads will save you a lot of computational time (and decrease the number of bad fits)
# - In many datasets, you wont need a strong diad category. In which case, everything will stay in the 'Medium' Category
# - Here, the best filter appears to be the prominence of the C13 peak, and the general elevation of the valley between diad and HB above the background outside the diad positions (Mean_Diad_HB variable).

# %%
var1='C13_abs_prom'
var2='Mean_Diad_HB_Valley_prom'
filter_bool_Strong=((fit_params_NotWeak[var1]>10)
                    |(fit_params_NotWeak[var2]>100))
# Here we make a plot of these parameters to better help select the right values
fig, (ax1) = plt.subplots(1, 1, figsize=(7,4))
ax1.plot(fit_params_NotWeak[var1].loc[filter_bool_Strong],
         fit_params_NotWeak[var2].loc[filter_bool_Strong], 'xr', label='Strong')
ax1.plot(fit_params_NotWeak[var1].loc[~filter_bool_Strong],
         fit_params_NotWeak[var2].loc[~filter_bool_Strong], 'xk', label='Medium')
#ax1.set_yscale('log')
#ax1.set_xscale('log')
ax1.set_xlabel(var1)
ax1.set_ylabel(var2)
ax1.legend()
#This makes a plot
fit_params_Strong, fit_params_Medium, data_y_Strong, data_y_Medium=pf.identify_diad_group(
    fit_params=fit_params_NotWeak.reset_index(drop=True), 
    data_y=data_y_NotWeak,x_cord=Diad[:, 0], 
    filter_bool=filter_bool_Strong, y_fig_scale=0.1, grp_filter='Medium-Strong')

# %% [markdown]
# ## Plot them all

# %%
fig=pf.plot_diad_groups(x_cord=Diad[:, 0], Weak_np=data_y_Weak,
                 Medium_np=data_y_Medium, Strong_np=data_y_Strong,
                   y_fig_scale=0.5)

# %% [markdown]
# ## Now lets save these lists, and we load them in another notebook

# %%
import joblib
joblib.dump(Diad[:, 0], 'np_x.sav')
joblib.dump(Diad[:, 1], 'np_y.sav')
joblib.dump(fit_params_Weak.reset_index(drop=True), 'Weak_df.sav')
joblib.dump(fit_params_Medium.reset_index(drop=True), 'Medium_df.sav')
joblib.dump(fit_params_Strong.reset_index(drop=True), 'Strong_df.sav')
fit_params_disc.to_excel('Discarded_df.xlsx')

# %%
fit_params_Weak
# Out:
#                       filename rays_present  approx_split    Diad1_pos  \
# 0   FDCA-P67-1_CRR_DiadFit.txt         True    103.310295  1285.282338
# 1               FDCA-P70-2.txt        False    103.145307  1285.590317
# 2               FDCA-P71-1.txt        False    103.156306  1285.639813
# 3               FDCA-P71-2.txt        False    103.194803  1285.639813
# 4   FDCA-P72-1_CRR_DiadFit.txt         True    103.244300  1285.694809
# 5               FDCA-P72-2.txt        False    103.244300  1285.689310
# 6               FDCA-P72-3.txt        False    103.244300  1285.689310
# 7               FDCA-P74-2.txt        False    103.106809  1285.936792
# 8               FDCA-P74-3.txt        False    103.090310  1285.953291
# 9               FDCA-P75-1.txt        False    102.991317  1286.079782
# 10              FDCA-P75-2.txt        False    102.991317  1286.079782
# 11              FDCA-P75-3.txt        False    102.996817  1286.074283
# 12              FDCA-P76-1.txt        False    102.996817  1286.101781
# 13              FDCA-P76-2.txt        False    102.969319  1286.134779
# 14  FDCA-P76-3_CRR_DiadFit.txt         True    102.985818  1286.101781
#
#       Diad2_pos      HB1_pos      HB2_pos  C13_pos  Diad1_abs_prom  \
# 0   1388.592633          NaN  1410.074135      NaN      596.186322
# 1   1388.735623  1265.280233  1410.162129      NaN      670.749300
# 2   1388.796119  1265.368227  1410.200626      NaN      777.040663
# 3   1388.834616          NaN  1410.206126      NaN      559.964597
# 4   1388.939109          NaN  1410.239124      NaN      428.672583
# 5   1388.933609          NaN  1410.250123      NaN      473.576907
# 6   1388.933609          NaN  1410.200626      NaN      457.182415
# 7   1389.043602  1265.549714  1410.277621      NaN      515.822718
# 8   1389.043602  1265.555214  1410.305119      NaN      496.797078
# 9   1389.071100          NaN  1410.316118      NaN      448.553693
# 10  1389.071100          NaN  1410.310619      NaN      422.604693
# 11  1389.071100          NaN  1410.338117      NaN      413.875390
# 12  1389.098598          NaN          NaN      NaN      123.712865
# 13  1389.104097          NaN          NaN      NaN      129.671506
# 14  1389.087599          NaN          NaN      NaN       98.903709
#
#     Diad2_abs_prom  ...  HB2_height  C13_height  Diad1_height  HB1_height  \
# 0      1109.722678  ...  811.713590         NaN   1328.786328         NaN
# 1      1061.546119  ...  816.370679         NaN   1399.549318  773.536490
# 2      1205.954214  ...  874.072618         NaN   1549.040663  822.309387
# 3       868.635769  ...  807.284837         NaN   1295.564572         NaN
# 4       678.746774  ...  807.845709         NaN   1171.972602         NaN
# 5       740.877099  ...  812.707131         NaN   1219.376895         NaN
# 6       736.747907  ...  813.345782         NaN   1202.882397         NaN
# 7       885.541501  ...  798.201074         NaN   1229.122736  755.400021
# 8       905.008627  ...  789.165275         NaN   1210.297078  759.209645
# 9       742.180320  ...  797.734330         NaN   1177.853680         NaN
# 10      717.856090  ...  797.119611         NaN   1152.804705         NaN
# 11      721.233628  ...  791.199515         NaN   1147.275384         NaN
# 12      209.378014  ...         NaN         NaN   1083.546178         NaN
# 13      187.851858  ...         NaN         NaN   1089.504850         NaN
# 14      173.757083  ...         NaN         NaN   1064.403709         NaN
#
#     Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         732.600006        737.650009                     NaN
# 1         728.800018        733.350021                     NaN
# 2         772.000000        778.750000                     NaN
# 3         735.599976        740.299988                     NaN
# 4         743.300018        748.400009                     NaN
# 5         745.799988        751.299988                     NaN
# 6         745.699982        751.699982                     NaN
# 7         713.300018        716.950012                     NaN
# 8         713.500000        717.000000                     NaN
# 9         729.299988        733.899994                     NaN
# 10        730.200012        734.550003                     NaN
# 11        733.399994        737.449997                     NaN
# 12        959.833313        977.999985                     NaN
# 13        959.833343        979.583328                     NaN
# 14        965.500000        986.250015                     NaN
#
#     Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  \
# 0                0.994295                        NaN
# 1                0.993032                  11.070205
# 2                0.983123                   9.951214
# 3                0.992277                        NaN
# 4                0.987058                        NaN
# 5                0.995730                        NaN
# 6                0.993994                        NaN
# 7                0.994396                  13.913386
# 8                0.994681                  14.853596
# 9                0.990140                        NaN
# 10               0.992061                        NaN
# 11               0.990986                        NaN
# 12                    NaN                        NaN
# 13                    NaN                        NaN
# 14                    NaN                        NaN
#
#     HB2_prom/std_betweendiads
# 0                    6.390237
# 1                   18.205655
# 2                   16.161773
# 3                   18.797224
# 4                   17.298771
# 5                   14.642490
# 6                   17.945110
# 7                   23.993795
# 8                   21.434877
# 9                   15.524284
# 10                  13.579945
# 11                  10.583699
# 12                        NaN
# 13                        NaN
# 14                        NaN
#
# [15 rows x 40 columns]

# %%
fit_params_Strong
# Out:
#                      filename rays_present  approx_split    Diad1_pos  \
# 0               FDCA-P1-1.txt        False    105.570637  1280.778152
# 1               FDCA-P1-2.txt        False    105.576137  1280.772653
# 2               FDCA-P1-3.txt        False    105.576137  1280.767153
# 3              FDCA-P10-1.txt        False    105.147167  1281.339113
# 4              FDCA-P10-2.txt        False    105.158166  1281.333613
# ..                        ...          ...           ...          ...
# 90              FDCA-P8-2.txt        False    105.229661  1281.212622
# 91              FDCA-P8-3.txt        False    105.213162  1281.223621
# 92              FDCA-P9-1.txt        False    105.185664  1281.278617
# 93              FDCA-P9-2.txt        False    105.191164  1281.267618
# 94  FDCA-P9-3_CRR_DiadFit.txt         True    105.180165  1281.278617
#
#       Diad2_pos      HB1_pos      HB2_pos      C13_pos  Diad1_abs_prom  \
# 0   1386.348790  1260.512065  1407.659803  1369.217484     4847.457414
# 1   1386.348790  1260.127092  1407.687301  1369.255982     5083.317217
# 2   1386.343290  1260.550563  1408.050276  1369.134990     4766.794313
# 3   1386.486280  1260.853042  1407.984281  1369.123991     5225.687184
# 4   1386.491780  1261.479998  1407.830291  1369.129490     5560.817810
# ..          ...          ...          ...          ...             ...
# 90  1386.442283  1260.787046  1407.665303  1369.107492     5214.275026
# 91  1386.436783  1261.144521  1408.094273  1369.068995     5456.034549
# 92  1386.464282  1261.199518  1407.978781  1369.101992     4719.727568
# 93  1386.458782  1261.067527  1408.176767  1369.107492     4868.474360
# 94  1386.458782  1261.144521  1407.896287  1369.123991     5357.377350
#
#     Diad2_abs_prom  ...   HB2_height  C13_height  Diad1_height  HB1_height  \
# 0      9482.707955  ...  1040.431258  963.903522   5573.657426  919.010349
# 1      9889.857815  ...  1059.938968  972.331543   5808.817217  916.425249
# 2      9232.841715  ...  1044.114609  955.661146   5491.994325  906.975638
# 3     10072.836657  ...  1086.902428  958.276249   5940.987172  922.964139
# 4     10777.556779  ...  1123.947027  984.270881   6280.817810  949.735171
# ..             ...  ...          ...         ...           ...         ...
# 90    10079.342283  ...  1084.140621  964.275501   5932.475038  920.745851
# 91    10511.477930  ...  1103.993654  979.660370   6176.134555  938.587919
# 92     9147.613182  ...  1044.942772  939.242766   5431.927580  903.399991
# 93     9464.731128  ...  1072.219243  949.374546   5584.774378  923.581644
# 94    10298.586042  ...  1095.601839  973.133850   6076.777344  941.518790
#
#     Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         726.200012        728.100006                2.253320
# 1         725.500000        727.799988                2.396952
# 2         725.200012        727.949997                2.398794
# 3         715.299988        717.449982                2.478250
# 4         720.000000        722.449997                2.470392
# ..               ...               ...                     ...
# 90        718.200012        720.250000                2.461787
# 91        720.100006        722.700012                2.372819
# 92        712.200012        714.150009                2.337473
# 93        716.300018        718.700012                2.483300
# 94        719.399994        721.550003                2.478129
#
#     Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  \
# 0                1.183347                  65.142963
# 1                1.182645                  65.252712
# 2                1.170953                  60.246187
# 3                1.162436                  92.393164
# 4                1.172328                 113.796863
# ..                    ...                        ...
# 90               1.173889                  86.203675
# 91               1.169587                 105.935648
# 92               1.156184                  91.431758
# 93               1.160878                  82.412593
# 94               1.171717                  97.737821
#
#     HB2_prom/std_betweendiads
# 0                   99.874680
# 1                  106.412839
# 2                   97.908421
# 3                  155.166521
# 4                  188.263579
# ..                        ...
# 90                 145.817503
# 91                 174.483003
# 92                 149.695294
# 93                 133.031554
# 94                 156.174424
#
# [95 rows x 40 columns]
