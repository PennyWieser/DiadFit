# %% [markdown]
# # 2. Filtering diad files into categories
# - This workbook shows how to filter diad files into 3 categories, to allow easier fitting
# - This data is from Devitre et al. (in review)

# %%
# Import useful python packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import DiadFit as pf
pf.__version__
# Out:
# '0.0.81'

# %% [markdown]
# ## Get the folder to your files
# - This loads in the information from Step1 of where you have stored things and file types

# %%
## This reads in the previous settings you set in Step1
meta_path, spectra_path, filetype, prefix, str_prefix, file_ext, TruPower=pf.get_settings()
# dont fit files with these strings in them
exclude_str=['Ne', 'NE', 'Si', 'nodiad', 'CRR', 'no_diad','test']

# %% [markdown]
# ## This function finds all files in your path with the specified file format
# - Specify information about your file formats here, as well as any text in filenames that you dont want to fit.

# %%
Diad_Files=pf.get_files(path=spectra_path, file_ext=file_ext, exclude_str=exclude_str)
print(Diad_Files)
# Out:
# ['04 187-1-105-reg2-B--Spectrum--004--Spec.Data 1.txt', '05 187-1-105-reg2-B--Spectrum--005--Spec.Data 1.txt', '06 187-1-105-reg2-B--Spectrum--006--Spec.Data 1.txt', '07 187-1-105-reg3-A--Spectrum--012--Spec.Data 1.txt', '09 187-1-105-reg3-A--Spectrum--016--Spec.Data 1.txt', '10 187-1-105-reg3-A--Spectrum--017--Spec.Data 1.txt', '12 187-1-105-reg3-B--Spectrum--021--Spec.Data 1.txt', '13 187-1-105-reg3-B--Spectrum--022--Spec.Data 1.txt', '14 187-1-105-reg3-B--Spectrum--023--Spec.Data 1.txt', '16 187-1-105-reg3-C--Spectrum--027--Spec.Data 1.txt', '17 187-1-105-reg3-C--Spectrum--028--Spec.Data 1.txt', '18 187-1-105-reg3-C--Spectrum--029--Spec.Data 1.txt', '19 187-1-105-reg4-A--Spectrum--031--Spec.Data 1.txt', '21 187-1-105-reg4-A--Spectrum--042--Spec.Data 1.txt', '23 187-1-105-reg4-A--Spectrum--044--Spec.Data 1.txt', '24 187-1-105-reg4-A--Spectrum--045--Spec.Data 1.txt', '26 187-1-105-reg4-B--Spectrum--049--Spec.Data 1.txt', '27 187-1-105-reg4-B--Spectrum--050--Spec.Data 1.txt', '28 187-1-105-reg4-B--Spectrum--051--Spec.Data 1.txt', '36 187-1-105-reg4-C--Spectrum--061--Spec.Data 1.txt', '37 187-1-105-reg4-C--Spectrum--062--Spec.Data 1.txt', '38 187-1-105-reg4-C--Spectrum--063--Spec.Data 1.txt', '40 187-1-106-A--Spectrum--074--Spec.Data 1.txt', '41 187-1-106-A--Spectrum--075--Spec.Data 1.txt', '42 187-1-106-A--Spectrum--076--Spec.Data 1.txt', '44 187-1-106-B--Spectrum--080--Spec.Data 1.txt', '45 187-1-106-B--Spectrum--081--Spec.Data 1.txt', '46 187-1-106-B--Spectrum--082--Spec.Data 1.txt', '48 187-1-107-A--Spectrum--091--Spec.Data 1.txt', '49 187-1-107-A--Spectrum--092--Spec.Data 1.txt', '50 187-1-107-A--Spectrum--093--Spec.Data 1.txt', '52 187-1-107-B--Spectrum--097--Spec.Data 1.txt', '53 187-1-107-B--Spectrum--098--Spec.Data 1.txt', '54 187-1-107-B--Spectrum--099--Spec.Data 1.txt', '55 187-1-107-A--Spectrum--100--Spec.Data 1.txt', '56 187-1-107-A--Spectrum--101--Spec.Data 1.txt', '57 187-1-107-A--Spectrum--102--Spec.Data 1.txt', '58 de.txt', '60 187-1-107-C--Spectrum--107--Spec.Data 1.txt', '61 187-1-107-C--Spectrum--108--Spec.Data 1.txt', '62 187-1-107-C--Spectrum--109--Spec.Data 1.txt', '70 187-1-107-D--Spectrum--120--Spec.Data 1.txt', '71 187-1-107-D--Spectrum--121--Spec.Data 1.txt', '72 187-1-107-D--Spectrum--122--Spec.Data 1.txt', '74 187-1-108-A--Spectrum--131--Spec.Data 1.txt', '75 187-1-108-A--Spectrum--132--Spec.Data 1.txt', '76 187-1-108-A--Spectrum--133--Spec.Data 1.txt', '78 187-1-109-A--Spectrum--140--Spec.Data 1.txt', '79 187-1-109-B--Spectrum--144--Spec.Data 1.txt', '80 187-1-109-B--Spectrum--145--Spec.Data 1.txt', '81 187-1-109-B--Spectrum--146--Spec.Data 1.txt', '82 187-1-109-C--Spectrum--149--Spec.Data 1.txt', '83 187-1-109-D--Spectrum--153--Spec.Data 1.txt', '85 187-1-110-A--Spectrum--158--Spec.Data 1.txt', '88 187-1-110-B--Spectrum--165--Spec.Data 1.txt']

# %%
help(pf.get_files)
# Out:
# Help on function get_files in module DiadFit.importing_data_files:
#
# get_files(path, ID_str=None, file_ext='txt', exclude_str=None, exclude_type=None, sort=True)
#     This function takes a user path, and extracts all files which contain the ID_str
#
#     Parameters
#     -----------
#
#     path: str
#         Folder user wishes to read data from
#     sort: bool
#         If true, sorts files alphabetically
#     ID_str: list
#         Finds all files containing this string (e.g. ['Ne', 'NE']
#     exclude_str: str
#         Excludes files with this string in the name
#     file_ext: str
#         Gets all files of this format only (e.g. txt)
#
#
#     Returns
#     -----------
#     list: file names as a list.

# %% [markdown]
# ## Find approximate peak positions
# - Tweak Scipy parameters to find the diad peaks
# - Tweak these parameters to make sure Scipy 'find_peaks' gets your diad peaks for your instrument.
# - Prominence: most useful parameter, required prominence of peaks
# - height: Minimum height of peaks, not that useful with various background positions
# - distance: Used to help with peaks that are very close to one another, smaller distance, remove peaks until keep set distance apart
# - width: Minimum width of peaks

# %%
# Tweak parameters away from the default here
diad_id_config=pf.diad_id_config(prominence=30, width=1)
diad_id_config
# Out:
# diad_id_config(height=1, width=1, prominence=30, plot_figure=True, exclude_range1=None, exclude_range2=None, approx_diad2_pos=(1379, 1395), approx_diad1_pos=(1275, 1290), Diad2_window=(1349, 1425), Diad1_window=(1245, 1290), approx_diad2_pos_3peaks=(1379, 1395, 1362))

# %%
# Check it has found the peaks of interest. Here we are looking at the 1st file

df_peaks, Diad, fig=pf.identify_diad_peaks(
config=diad_id_config, 
path=spectra_path, filename=Diad_Files[0],
filetype=filetype, plot_figure=True)
df_peaks
# Out:
#                                             filename  approx_split  \
# 1  04 187-1-105-reg2-B--Spectrum--004--Spec.Data ...    103.794261
#
#      Diad1_pos    Diad2_pos  HB1_pos  HB2_pos  C13_pos  Diad1_abs_prom  \
# 1  1284.462895  1388.257157      NaN      NaN      NaN       152.18751
#
#    Diad2_abs_prom  HB1_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 1      305.843799           NaN  ...         NaN         NaN    822.287516
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 1         NaN        670.100006             669.5                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 1                    NaN                        NaN                        NaN
#
# [1 rows x 39 columns]

# %% [markdown]
# ### Now you have looked at a few files and are happy with these parameters, loop over all files to get approximate fit parameters for all your diad acquisitions

# %%
fit_params, data_y_all=pf.loop_approx_diad_fits(spectra_path=spectra_path, config=diad_id_config, 
                       Diad_Files=Diad_Files, filetype=filetype, plot_figure=False)
fit_params.head()
# Out:
#   0%|          | 0/55 [00:00<?, ?it/s]
# 100%|██████████| 55/55 [00:02<00:00, 18.55it/s]
#                                             filename  approx_split  \
# 0  04 187-1-105-reg2-B--Spectrum--004--Spec.Data ...    103.794261
# 1  05 187-1-105-reg2-B--Spectrum--005--Spec.Data ...    103.860257
# 2  06 187-1-105-reg2-B--Spectrum--006--Spec.Data ...    103.805261
# 3  07 187-1-105-reg3-A--Spectrum--012--Spec.Data ...    104.030745
# 4  09 187-1-105-reg3-A--Spectrum--016--Spec.Data ...    104.069242
#
#      Diad1_pos    Diad2_pos  HB1_pos  HB2_pos  C13_pos  Diad1_abs_prom  \
# 0  1284.462895  1388.257157      NaN      NaN      NaN      152.187510
# 1  1284.429897  1388.290154      NaN      NaN      NaN      144.371836
# 2  1284.517891  1388.323152      NaN      NaN      NaN      130.067923
# 3  1284.022926  1388.053671      NaN      NaN      NaN      123.938438
# 4  1283.989928  1388.059170      NaN      NaN      NaN      133.008829
#
#    Diad2_abs_prom  HB1_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 0      305.843799           NaN  ...         NaN         NaN    822.287516
# 1      302.656870           NaN  ...         NaN         NaN    813.671824
# 2      267.872238           NaN  ...         NaN         NaN    798.067923
# 3      269.072575           NaN  ...         NaN         NaN    784.638419
# 4      278.709591           NaN  ...         NaN         NaN    794.808816
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         NaN        670.100006        669.500000                     NaN
# 1         NaN        669.299988        668.699982                     NaN
# 2         NaN        668.000000        667.150009                     NaN
# 3         NaN        660.699982        660.199982                     NaN
# 4         NaN        661.799988        661.249985                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                    NaN                        NaN                        NaN
# 1                    NaN                        NaN                        NaN
# 2                    NaN                        NaN                        NaN
# 3                    NaN                        NaN                        NaN
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 39 columns]

# %% [markdown]
# ## Check for duplicates now!

# %%
file_s=pf.extracting_filenames_generic(
    names=fit_params['filename'].reset_index(drop=True),
prefix=prefix, str_prefix=str_prefix,
   file_ext=file_ext)
# Out:
# good job, no duplicate file names

# %% [markdown]
# ## Filter out spectra with Cosmic rays

# %% [markdown]
# ### Pick a spectra to tweak first

# %%
Diad_files=fit_params['filename']
i=0
filename_select=Diad_files.iloc[i] 
print(Diad_Files[i])
plot1=pf.plot_diad(path=spectra_path, filename=filename_select, filetype=filetype)
# Out:
# 04 187-1-105-reg2-B--Spectrum--004--Spec.Data 1.txt

# %% [markdown]
# ### Pick your other parameters
#
# NOTE that you can also change the number of neighbors considered in the intensity factor (n),but n=1 is often the best. dynfact is the intensity factor cutoff above which pixels are considered outliers in the first pass (y axis on the first plot on the leftmost). dynfact_2 is the same, but for the second pass. The filter automatically disregards pixels that are known to be of interest (here diads, hbs and c13).

# %%
# This extract the peaks for the diads, HBs and C13 from fit_params_crr, essential to the CRR process.
diad_peaks=fit_params[['Diad1_pos','Diad2_pos','HB1_pos','HB2_pos','C13_pos']]

#Pick your settings
plot_rays='rays_only'#whether to plot the results or not
export_cleanspec=True #whether to export the spectra with the cosmic ray pixels removed
save_fig='all' #whether to save the figures, options are 'all' or the default 'rays_only'
dynfact=0.001 #dynamic intensity factor for the first pass (y axis on the leftmost plots)
dynfact_2=0.001#dynamic intensity factor for the second pass
n=1 # number of neighboring pixels being compared, typically 1 is ideal.

exclude_ranges=[(1100,1200)] # List of tuples containing ranges to exclude from filtering (i.e., for secondary peaks

# %% [markdown]
# ### Run the filter on the selected spectra
# - rays_found is a dataframe containing the filename and whether cosmic rays were found. spectrum is the filtered spectrum in the form of a dataframe.
# - It contains nan values where the cosmic rays are. It is NOT for fitting.

# %%
rays_found,spectrum=pf.cosmicray_filter.filter_singleray(path=spectra_path,
                                        exclude_ranges=exclude_ranges,filetype=filetype,
                                        Diad_files=Diad_files,i=i,diad_peaks=diad_peaks,plot_rays=plot_rays,
                                      export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n)
# Out:
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 04 187-1-105-reg2-B--Spectrum--004--Spec.Data 1.txt
# headless_txt

# %% [markdown]
# ###  Loop over all other spectra
# the output of this is the data_y_all file, which contains plottable spectra and the new fit_params file with filtered spectra

# %%
data_y_all_crr,fit_params_crr=pf.cosmicray_filter.filter_raysinloop(Diad_files=Diad_files, spectra_path=spectra_path, 
                exclude_ranges=exclude_ranges,
                    fit_params=fit_params, diad_peaks=diad_peaks,plot_rays=plot_rays,
                    export_cleanspec=export_cleanspec,save_fig=save_fig,dynfact=dynfact,dynfact_2=dynfact_2,n=n)
# Out:
#   2%|▏         | 1/55 [00:00<00:08,  6.39it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 04 187-1-105-reg2-B--Spectrum--004--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 05 187-1-105-reg2-B--Spectrum--005--Spec.Data 1.txt
# headless_txt
#   5%|▌         | 3/55 [00:00<00:08,  6.28it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 06 187-1-105-reg2-B--Spectrum--006--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 07 187-1-105-reg3-A--Spectrum--012--Spec.Data 1.txt
# headless_txt
#  13%|█▎        | 7/55 [00:00<00:03, 13.06it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 09 187-1-105-reg3-A--Spectrum--016--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 10 187-1-105-reg3-A--Spectrum--017--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 12 187-1-105-reg3-B--Spectrum--021--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 13 187-1-105-reg3-B--Spectrum--022--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 14 187-1-105-reg3-B--Spectrum--023--Spec.Data 1.txt
# headless_txt
#  22%|██▏       | 12/55 [00:00<00:02, 17.23it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 16 187-1-105-reg3-C--Spectrum--027--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 17 187-1-105-reg3-C--Spectrum--028--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 18 187-1-105-reg3-C--Spectrum--029--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 19 187-1-105-reg4-A--Spectrum--031--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 21 187-1-105-reg4-A--Spectrum--042--Spec.Data 1.txt
# headless_txt
#  31%|███       | 17/55 [00:01<00:02, 18.89it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 23 187-1-105-reg4-A--Spectrum--044--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 24 187-1-105-reg4-A--Spectrum--045--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 26 187-1-105-reg4-B--Spectrum--049--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 27 187-1-105-reg4-B--Spectrum--050--Spec.Data 1.txt
# headless_txt
#  36%|███▋      | 20/55 [00:01<00:02, 14.73it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 28 187-1-105-reg4-B--Spectrum--051--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 36 187-1-105-reg4-C--Spectrum--061--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 37 187-1-105-reg4-C--Spectrum--062--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 38 187-1-105-reg4-C--Spectrum--063--Spec.Data 1.txt
# headless_txt
#  42%|████▏     | 23/55 [00:01<00:02, 13.92it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 40 187-1-106-A--Spectrum--074--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 41 187-1-106-A--Spectrum--075--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 42 187-1-106-A--Spectrum--076--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 44 187-1-106-B--Spectrum--080--Spec.Data 1.txt
# headless_txt
#  53%|█████▎    | 29/55 [00:02<00:01, 16.27it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 45 187-1-106-B--Spectrum--081--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 46 187-1-106-B--Spectrum--082--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 48 187-1-107-A--Spectrum--091--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 49 187-1-107-A--Spectrum--092--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 50 187-1-107-A--Spectrum--093--Spec.Data 1.txt
# headless_txt
#  60%|██████    | 33/55 [00:02<00:01, 12.62it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 52 187-1-107-B--Spectrum--097--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 53 187-1-107-B--Spectrum--098--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 54 187-1-107-B--Spectrum--099--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 55 187-1-107-A--Spectrum--100--Spec.Data 1.txt
# headless_txt
#  64%|██████▎   | 35/55 [00:02<00:01, 12.78it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 56 187-1-107-A--Spectrum--101--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 57 187-1-107-A--Spectrum--102--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 58 de.txt
# headless_txt
#  73%|███████▎  | 40/55 [00:03<00:01, 13.17it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 60 187-1-107-C--Spectrum--107--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 61 187-1-107-C--Spectrum--108--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 62 187-1-107-C--Spectrum--109--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 70 187-1-107-D--Spectrum--120--Spec.Data 1.txt
# headless_txt
#  76%|███████▋  | 42/55 [00:03<00:01, 11.51it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 71 187-1-107-D--Spectrum--121--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 72 187-1-107-D--Spectrum--122--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 74 187-1-108-A--Spectrum--131--Spec.Data 1.txt
# headless_txt
#  87%|████████▋ | 48/55 [00:03<00:00, 12.87it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 75 187-1-108-A--Spectrum--132--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 76 187-1-108-A--Spectrum--133--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 78 187-1-109-A--Spectrum--140--Spec.Data 1.txt
# headless_txt
#  91%|█████████ | 50/55 [00:03<00:00, 13.65it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 79 187-1-109-B--Spectrum--144--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 80 187-1-109-B--Spectrum--145--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 81 187-1-109-B--Spectrum--146--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 82 187-1-109-C--Spectrum--149--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 83 187-1-109-D--Spectrum--153--Spec.Data 1.txt
# headless_txt
# 100%|██████████| 55/55 [00:04<00:00, 13.73it/s]
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 85 187-1-110-A--Spectrum--158--Spec.Data 1.txt
# headless_txt
# p:\WORK-GENERAL\POSTDOC-UCB\BERKELEY-VIBE\Documents\Projects\Undergrad_projects\Kama'ehuakanaloa\Data\Raman\Kamae'huakanaloa_1-11-24\Spectra
# 88 187-1-110-B--Spectrum--165--Spec.Data 1.txt
# headless_txt
#                                             filename rays_present  \
# 0  04 187-1-105-reg2-B--Spectrum--004--Spec.Data ...         True
# 1  05 187-1-105-reg2-B--Spectrum--005--Spec.Data ...         True
# 2  06 187-1-105-reg2-B--Spectrum--006--Spec.Data ...         True
# 3  07 187-1-105-reg3-A--Spectrum--012--Spec.Data ...         True
# 4  09 187-1-105-reg3-A--Spectrum--016--Spec.Data ...        False
#
#    approx_split    Diad1_pos    Diad2_pos  HB1_pos  HB2_pos  C13_pos  \
# 0    103.794261  1284.462895  1388.257157      NaN      NaN      NaN
# 1    103.860257  1284.429897  1388.290154      NaN      NaN      NaN
# 2    103.805261  1284.517891  1388.323152      NaN      NaN      NaN
# 3    104.030745  1284.022926  1388.053671      NaN      NaN      NaN
# 4    104.069242  1283.989928  1388.059170      NaN      NaN      NaN
#
#    Diad1_abs_prom  Diad2_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 0      152.187510      305.843799  ...         NaN         NaN    822.287516
# 1      144.371836      302.656870  ...         NaN         NaN    813.671824
# 2      130.067923      267.872238  ...         NaN         NaN    798.067923
# 3      123.938438      269.072575  ...         NaN         NaN    784.638419
# 4      133.008829      278.709591  ...         NaN         NaN    794.808816
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         NaN        670.100006        669.500000                     NaN
# 1         NaN        669.299988        668.699982                     NaN
# 2         NaN        668.000000        667.150009                     NaN
# 3         NaN        660.699982        660.199982                     NaN
# 4         NaN        661.799988        661.249985                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                    NaN                        NaN                        NaN
# 1                    NaN                        NaN                        NaN
# 2                    NaN                        NaN                        NaN
# 3                    NaN                        NaN                        NaN
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Plot peak parameters
# - This will help you inspect clear cut offs you can use to split your diads into groups for fitting
# - You can enter different x and y coordinates from the dataframe headings above
# - In this example, there are no clear groups, because all the spectra are weak (see paper for definition). This means we place them all in the weak category.

# %%
fig=pf.plot_peak_params(fit_params=fit_params_crr, 
                     x_param='Diad1_pos',  y1_param='approx_split',
                    y2_param='Diad1_abs_prom', y3_param='C13_abs_prom',
                    y4_param='Diad1_prom/std_betweendiads', fill_na=0)

# %%
fit_params_crr.head()
# Out:
#                                             filename rays_present  \
# 0  04 187-1-105-reg2-B--Spectrum--004--Spec.Data ...         True
# 1  05 187-1-105-reg2-B--Spectrum--005--Spec.Data ...         True
# 2  06 187-1-105-reg2-B--Spectrum--006--Spec.Data ...         True
# 3  07 187-1-105-reg3-A--Spectrum--012--Spec.Data ...         True
# 4  09 187-1-105-reg3-A--Spectrum--016--Spec.Data ...        False
#
#    approx_split    Diad1_pos    Diad2_pos  HB1_pos  HB2_pos  C13_pos  \
# 0    103.794261  1284.462895  1388.257157      NaN      NaN      NaN
# 1    103.860257  1284.429897  1388.290154      NaN      NaN      NaN
# 2    103.805261  1284.517891  1388.323152      NaN      NaN      NaN
# 3    104.030745  1284.022926  1388.053671      NaN      NaN      NaN
# 4    104.069242  1283.989928  1388.059170      NaN      NaN      NaN
#
#    Diad1_abs_prom  Diad2_abs_prom  ...  HB2_height  C13_height  Diad1_height  \
# 0      152.187510      305.843799  ...         NaN         NaN    822.287516
# 1      144.371836      302.656870  ...         NaN         NaN    813.671824
# 2      130.067923      267.872238  ...         NaN         NaN    798.067923
# 3      123.938438      269.072575  ...         NaN         NaN    784.638419
# 4      133.008829      278.709591  ...         NaN         NaN    794.808816
#
#    HB1_height  Diad1_Median_Bck  Diad2_Median_Bck  C13_HB2_abs_prom_ratio  \
# 0         NaN        670.100006        669.500000                     NaN
# 1         NaN        669.299988        668.699982                     NaN
# 2         NaN        668.000000        667.150009                     NaN
# 3         NaN        660.699982        660.199982                     NaN
# 4         NaN        661.799988        661.249985                     NaN
#
#    Diad2_HB2_Valley_prom  HB1_prom/std_betweendiads  HB2_prom/std_betweendiads
# 0                    NaN                        NaN                        NaN
# 1                    NaN                        NaN                        NaN
# 2                    NaN                        NaN                        NaN
# 3                    NaN                        NaN                        NaN
# 4                    NaN                        NaN                        NaN
#
# [5 rows x 40 columns]

# %% [markdown]
# ### Filter out ones with really bad splitting or really low diad prominence
# - Here, we only take files with splitting between 101-108 (you will need to tweak this for each instrument)
# - We also only take files with a prominence of diad 1 >10
# - You can also choose to discard based on a specific string in the file name - excxlude exclude_str='noisy'
# - None here got filtered out, but these can be helpful filters on other datasets

# %%
fit_params_filt, data_y_filt, fit_params_disc, data_y_disc=pf.filter_splitting_prominence(
fit_params=fit_params_crr, data_y_all=data_y_all, x_cord=Diad[:, 0],
splitting_limits=[101, 108], lower_diad1_prom=10, exclude_str=None)
# Out:
# Keeping N=53
# Discarding N=2

# %% [markdown]
# ### Now apply filters to find the weakest diads (e.g. ones you wouldnt want to fit a hotband too)
# - In this case, we find the best filters are the position of Diad1 (shifts way more than Diad2),
# and where HB2 had a prominence (e.g., not nan because it wasnt found)
# - We find it also helpful to apply a filter, e.g. weak is Diad1pos<1287 or HB2 prominence nan, and  the prominence of Diad1 is <300X the standard deviation of the diad region

# %%
var='Diad1_pos'
plt.hist(fit_params_filt[var])
# Out:
# (array([10.,  2.,  3., 13.,  3.,  6.,  7.,  6.,  0.,  3.]),
#  array([1283.22548145, 1283.48451339, 1283.74354532, 1284.00257726,
#         1284.26160919, 1284.52064113, 1284.77967306, 1285.038705  ,
#         1285.29773693, 1285.55676887, 1285.8158008 ]),
#  <BarContainer object of 10 artists>)

# %%
# Here we put spectra in the weak group if diad1 position is >1285.5 or if the av prominence of the diad relative to the standard deviation is <150

Filter2=(fit_params_filt['Av_Diad_prom/std_betweendiads']<150)
Filter3=fit_params_filt['Diad2_prom/std_betweendiads']<1100
Filter4=fit_params_filt['Diad1_pos']>1283
filter_bool=Filter4 
fit_params_Weak, fit_params_NotWeak, data_y_Weak, data_y_NotWeak=pf.identify_diad_group(
    fit_params=fit_params_filt, 
     data_y=data_y_filt, 
    x_cord=Diad[:, 0], 
    y_fig_scale=0.3,
    filter_bool=filter_bool, grp_filter='Weak')

# %% [markdown]
# ## Seperate Medium and strong diads
# - Now we need to find something that separates out strong diads from medium strength diads
# - The aim here is to get diads that are sufficiently strong that you have to fit a gaussian background in addition to diads, hbs and C13 peaks. Not having to fit a gaussian background to medium density diads will save you a lot of computational time (and decrease the number of bad fits)
# - In many datasets, you wont need a strong diad category. In which case, everything will stay in the 'Medium' Category
# - Here, the best filter appears to be the prominence of the C13 peak, and the general elevation of the valley between diad and HB above the background outside the diad positions (Mean_Diad_HB variable).

# %%
var1='C13_abs_prom'
var2='Mean_Diad_HB_Valley_prom'
filter_bool_Strong=((fit_params_NotWeak[var1]>100)
                    &(fit_params_NotWeak[var2]>100))
# Here we make a plot of these parameters to better help select the right values
if sum(filter_bool_Strong)>0:
    fig, (ax1) = plt.subplots(1, 1, figsize=(7,4))
    ax1.plot(fit_params_NotWeak[var1].loc[filter_bool_Strong],
            fit_params_NotWeak[var2].loc[filter_bool_Strong], 'xr', label='Strong')
    ax1.plot(fit_params_NotWeak[var1].loc[~filter_bool_Strong],
            fit_params_NotWeak[var2].loc[~filter_bool_Strong], 'xk', label='Medium')

    ax1.set_yscale('log')
    ax1.set_xscale('log')
    ax1.set_xlabel(var1)
    ax1.set_ylabel(var2)
    ax1.legend()
#This makes a plot
fit_params_Strong, fit_params_Medium, data_y_Strong, data_y_Medium=pf.identify_diad_group(
    fit_params=fit_params_NotWeak.reset_index(drop=True), 
    data_y=data_y_NotWeak,x_cord=Diad[:, 0], 
    filter_bool=filter_bool_Strong, y_fig_scale=0.2, grp_filter='Medium-Strong')

# %% [markdown]
# ## Plot them all

# %%
fig=pf.plot_diad_groups(x_cord=Diad[:, 0], Weak_np=data_y_Weak,
                 Medium_np=data_y_Medium, Strong_np=data_y_Strong,
                   y_fig_scale=0.5)

# %% [markdown]
# ## Now lets save these lists, and we load them in another notebook

# %%
import joblib
joblib.dump(Diad[:, 0], 'np_x.sav')
joblib.dump(Diad[:, 1], 'np_y.sav')
joblib.dump(fit_params_Weak.reset_index(drop=True), 'Weak_df.sav')
joblib.dump(fit_params_Medium.reset_index(drop=True), 'Medium_df.sav')
joblib.dump(fit_params_Strong.reset_index(drop=True), 'Strong_df.sav')
fit_params_disc.to_excel('Discarded_df.xlsx')
